# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms

from torch.nn import functional as F

import time
import math

# %%
device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
def create_data_loader(batch_size):
  # Split the provided CIFAR-10 train set (50,000 images) into your train and val sets
  # Use the first 40,000 images as your train set and the remaining 10,000 images as val set
  # Use all 10,000 images in the provided test set as your test set

  transform = transforms.Compose([
    transforms.ToTensor(),
      # This is the mean and the average of the cifar db because we are normalizing it.
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)), 
  ])

  # load cifar
  train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
  test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

  # split train set into train and val
  train_set, val_set = torch.utils.data.random_split(train_set, [40000, 10000])

  # create data loaders
  train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,num_workers=4)
  val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=True,num_workers=4)
  test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True,num_workers=4)

  train_loader = [(inputs.to(device), labels.to(device)) for inputs, labels in train_loader]
  val_loader = [(inputs.to(device), labels.to(device)) for inputs, labels in val_loader]
  test_loader = [(inputs.to(device), labels.to(device)) for inputs, labels in test_loader]




  return train_loader, val_loader, test_loader

# %%
class QuasiPolySynapse(nn.Module):
    def __init__(self):
        super().__init__() 
        self.main = nn.ParameterList([torch.randn(1),torch.tensor([1.],requires_grad=False)])
        # self.main = nn.ParameterList([torch.randn(1)])
        self.terms = nn.ParameterList()

        
    def forward(self, x):
        if  len(self.terms) < math.floor(self.main[1]) - 1:
            self.add_term()
        y = self.main[0] * x ** self.main[1]
        for idx,coeff in enumerate(self.terms):
             y = y + coeff * x**(idx+1)
        return y

    def add_term(self):
        print("Adding term")
        # Add new term, init coeff to 1. non-trainable exponent to floor of main exponent
        self.terms.append(nn.Parameter(torch.tensor([1.])))

    def __str__(self):
        s = ""
        s += f"Main: {self.main[0]}x^{self.main[1]} + "
        for idx,term in enumerate(self.terms):
            s += f"{term}x^{idx+1} + "
        return s[:-3]



class QuasiPolyLayer(nn.Module):
  def __init__(self, in_features, out_features, product=False):
    super().__init__()
    self.out_features = out_features
    self.in_features = in_features
    # a 2d module list of quasipoly synapses sizes in_features x out_features
    self.synapses = nn.ModuleList([
        nn.ModuleList([QuasiPolySynapse() for _ in range(self.in_features)])
        for _ in range(self.out_features)
    ])
    self.bias = nn.Parameter(torch.randn(out_features))
    self.product = product
  
  def forward(self, x):
    batch_size = x.shape[0]
    y = torch.zeros(batch_size, self.out_features, dtype=torch.float32)

    for i in range(self.out_features):
        if self.product:
            log_sum = torch.zeros(batch_size, dtype=torch.float32)
        else:
            y_i = torch.zeros(batch_size, dtype=torch.float32)

        for j in range(self.in_features):
            x_j = x[:, j]
            synapse_output = self.synapses[i][j](x_j)
            # print(f"syanpse_output {synapse_output}")
            if self.product:
                # Assuming you have a tensor named 'tensor' and a threshold value
                threshold = 1e-4
                synapse_output = torch.where(synapse_output < threshold, threshold, synapse_output)
                log_sum = log_sum + torch.log(synapse_output) 
            else:
                y_i = y_i + synapse_output

        if self.product:
            log_sum_max, _ = torch.max(log_sum, dim=0, keepdim=True)
            # print(f"log_sum {log_sum} log_sum_max {log_sum_max}")
            y[:, i] = torch.exp(log_sum - log_sum_max)
        else:
            y[:, i] = y_i

    y = y + self.bias

    return y
  


class AddEpsilon(nn.Module):
    def __init__(self, epsilon=1e-10): # 1e-10 is smallest possible float in pytorch
        super().__init__()
        self.epsilon = epsilon

    def forward(self, x):
        return x + self.epsilon

    

class LeNet5(nn.Module):

    def __init__(self, num_classes, grayscale=False):
        super(LeNet5, self).__init__()
        
        self.grayscale = grayscale
        self.num_classes = num_classes

        in_channels = 3 # because cifar10 is colored

        self.features = nn.Sequential(
            
            nn.Conv2d(in_channels, 6*in_channels, kernel_size=5),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=2),
            nn.Conv2d(6*in_channels, 16*in_channels, kernel_size=5),
            nn.Tanh(),
            nn.MaxPool2d(kernel_size=2)
        )

        self.classifier = nn.Sequential(
            nn.Linear(16*5*5*in_channels, 84*in_channels),  
            nn.ReLU(),
            # nn.Linear(120*in_channels, 84*in_channels),
            # QuasiPolyLayer(60*in_channels, 21*in_channels),
            nn.ReLU(),
            # nn.Linear(84*in_channels, num_classes)
            AddEpsilon(),
            QuasiPolyLayer(84*in_channels, num_classes, product=True)
        )


    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        logits = self.classifier(x)
        return logits

# %%
def init_train_var(model):
  
  criterion = nn.CrossEntropyLoss()
  # optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.2,weight_decay=0.001) # set momentum to 0.2 after trial and error
  # optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.00001)
  optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

  return criterion, optimizer

# %%
def test(model_path, test_loader):
  # use the provided test loader
  # return the test accuracy
  model = torch.load(model_path)
  model.eval()
  with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
      outputs = model(images)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()
    test_acc = correct / total
  return test_acc

# %%
BATCH_SIZE = 1024
train_loader, val_loader, test_loader = create_data_loader(batch_size=BATCH_SIZE)

EPOCH_COUNT = 30

model = LeNet5(10)
model = model.to(device)
model = nn.DataParallel(model)
criterion, optimizer = init_train_var(model)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# %%time

for epoch in range(EPOCH_COUNT):
    model.train()
    train_loss = 0
    train_correct = 0
    # for each batch
    for i, (inputs, labels) in enumerate(train_loader):
        # count the number of weights with very small magnitute < 1e-3
        nans_count = 0
        for param in model.parameters():
            if param.grad is not None:
                nans_count += torch.sum(torch.isnan(param.grad)).item()
        
        print(f"nans count: {nans_count}")
        
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(inputs)
        # print(f"outputs {outputs}")
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        # print all gradients of the first synapse
        # print(f"synapse grads : {model.classifier[-1].synapses[0][0].main[0].grad}")
        # print(f"weights of first layer {model.classifier[-1].synapses[0][0]}")
        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        train_correct += (predicted == labels).sum().item()


    print(f'Epoch {epoch+1}/{EPOCH_COUNT}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_correct/40000:.4f}')
    # validate
    model.eval()
    val_loss = 0
    val_correct = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels).sum().item()
    val_acc = val_correct/10000
    print(f'Epoch {epoch+1}/{EPOCH_COUNT}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.4f}')
# Out:
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 1/30, Train Loss: 101.5030, Train Accuracy: 0.0994
# Epoch 1/30, Val Loss: 25.1924, Val Accuracy: 0.1025
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 2/30, Train Loss: 100.6118, Train Accuracy: 0.0995
# Epoch 2/30, Val Loss: 24.9861, Val Accuracy: 0.1022
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 3/30, Train Loss: 99.7825, Train Accuracy: 0.0993
# Epoch 3/30, Val Loss: 24.7896, Val Accuracy: 0.1026
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 4/30, Train Loss: 99.0509, Train Accuracy: 0.0994
# Epoch 4/30, Val Loss: 24.6281, Val Accuracy: 0.1022
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 5/30, Train Loss: 98.4040, Train Accuracy: 0.0995
# Epoch 5/30, Val Loss: 24.4669, Val Accuracy: 0.1024
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 6/30, Train Loss: 97.7533, Train Accuracy: 0.0993
# Epoch 6/30, Val Loss: 24.3319, Val Accuracy: 0.1024
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 7/30, Train Loss: 97.1924, Train Accuracy: 0.0994
# Epoch 7/30, Val Loss: 24.1977, Val Accuracy: 0.1026
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 8/30, Train Loss: 96.6808, Train Accuracy: 0.0995
# Epoch 8/30, Val Loss: 24.0787, Val Accuracy: 0.1030
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 9/30, Train Loss: 96.1968, Train Accuracy: 0.0994
# Epoch 9/30, Val Loss: 23.9705, Val Accuracy: 0.1026
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 10/30, Train Loss: 95.7325, Train Accuracy: 0.0997
# Epoch 10/30, Val Loss: 23.8369, Val Accuracy: 0.1027
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 11/30, Train Loss: 95.3642, Train Accuracy: 0.0996
# Epoch 11/30, Val Loss: 23.7415, Val Accuracy: 0.1025
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 12/30, Train Loss: 94.8996, Train Accuracy: 0.0993
# Epoch 12/30, Val Loss: 23.6605, Val Accuracy: 0.1024
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 13/30, Train Loss: 94.6139, Train Accuracy: 0.0995
# Epoch 13/30, Val Loss: 23.5976, Val Accuracy: 0.1021
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 14/30, Train Loss: 94.3677, Train Accuracy: 0.1001
# Epoch 14/30, Val Loss: 23.5535, Val Accuracy: 0.1030
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 15/30, Train Loss: 94.1053, Train Accuracy: 0.1003
# Epoch 15/30, Val Loss: 23.4577, Val Accuracy: 0.1044
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 16/30, Train Loss: 93.9303, Train Accuracy: 0.1003
# Epoch 16/30, Val Loss: 23.4547, Val Accuracy: 0.1037
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 17/30, Train Loss: 93.7945, Train Accuracy: 0.0999
# Epoch 17/30, Val Loss: 23.4223, Val Accuracy: 0.1022
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 18/30, Train Loss: 93.6259, Train Accuracy: 0.0999
# Epoch 18/30, Val Loss: 23.3727, Val Accuracy: 0.1028
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 19/30, Train Loss: 93.4430, Train Accuracy: 0.0992
# Epoch 19/30, Val Loss: 23.3347, Val Accuracy: 0.1024
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 20/30, Train Loss: 93.2739, Train Accuracy: 0.0993
# Epoch 20/30, Val Loss: 23.3001, Val Accuracy: 0.1026
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 21/30, Train Loss: 93.1553, Train Accuracy: 0.0992
# Epoch 21/30, Val Loss: 23.2616, Val Accuracy: 0.1037
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 22/30, Train Loss: 93.0324, Train Accuracy: 0.0999
# Epoch 22/30, Val Loss: 23.2275, Val Accuracy: 0.1047
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 23/30, Train Loss: 92.8992, Train Accuracy: 0.1007
# Epoch 23/30, Val Loss: 23.2027, Val Accuracy: 0.1043
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 24/30, Train Loss: 92.7518, Train Accuracy: 0.1014
# Epoch 24/30, Val Loss: 23.1787, Val Accuracy: 0.1048
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 25/30, Train Loss: 92.6356, Train Accuracy: 0.1027
# Epoch 25/30, Val Loss: 23.1490, Val Accuracy: 0.1072
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 26/30, Train Loss: 92.5584, Train Accuracy: 0.1041
# Epoch 26/30, Val Loss: 23.1373, Val Accuracy: 0.1063
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 27/30, Train Loss: 92.4960, Train Accuracy: 0.1040
# Epoch 27/30, Val Loss: 23.1339, Val Accuracy: 0.1059
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 28/30, Train Loss: 92.3931, Train Accuracy: 0.1059
# Epoch 28/30, Val Loss: 23.1041, Val Accuracy: 0.1079
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 29/30, Train Loss: 92.3655, Train Accuracy: 0.1046
# Epoch 29/30, Val Loss: 23.0991, Val Accuracy: 0.1054
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# nans count: 0
# Epoch 30/30, Train Loss: 92.2580, Train Accuracy: 0.1065
# Epoch 30/30, Val Loss: 23.0725, Val Accuracy: 0.1086
# CPU times: user 1h 33min 27s, sys: 2min 25s, total: 1h 35min 52s
# Wall time: 30min 35s

# %%
# print weights of quasi poly layer

quasi_poly_layer = model.module.classifier[-1]
for i in range(quasi_poly_layer.out_features):
    for j in range(quasi_poly_layer.in_features):
        synapse = quasi_poly_layer.synapses[i][j]
        print(f"Weights of synapse ({i}, {j}): {synapse}")
# Out:
# Weights of synapse (0, 0): Main: Parameter containing:
# tensor([0.9256], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 1): Main: Parameter containing:
# tensor([-1.6803], requires_grad=True)x^Parameter containing:
# tensor([0.9974], requires_grad=True)
# Weights of synapse (0, 2): Main: Parameter containing:
# tensor([-1.7774], requires_grad=True)x^Parameter containing:
# tensor([0.9984], requires_grad=True)
# Weights of synapse (0, 3): Main: Parameter containing:
# tensor([1.3900], requires_grad=True)x^Parameter containing:
# tensor([1.0010], requires_grad=True)
# Weights of synapse (0, 4): Main: Parameter containing:
# tensor([-1.5643], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 5): Main: Parameter containing:
# tensor([-0.4038], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 6): Main: Parameter containing:
# tensor([0.6651], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (0, 7): Main: Parameter containing:
# tensor([0.1041], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 8): Main: Parameter containing:
# tensor([0.8110], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 9): Main: Parameter containing:
# tensor([2.2743], requires_grad=True)x^Parameter containing:
# tensor([1.0008], requires_grad=True)
# Weights of synapse (0, 10): Main: Parameter containing:
# tensor([-0.2657], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 11): Main: Parameter containing:
# tensor([-1.0693], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 12): Main: Parameter containing:
# tensor([2.2302], requires_grad=True)x^Parameter containing:
# tensor([0.9994], requires_grad=True)
# Weights of synapse (0, 13): Main: Parameter containing:
# tensor([0.9298], requires_grad=True)x^Parameter containing:
# tensor([1.0007], requires_grad=True)
# Weights of synapse (0, 14): Main: Parameter containing:
# tensor([-0.7814], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 15): Main: Parameter containing:
# tensor([2.7068], requires_grad=True)x^Parameter containing:
# tensor([0.9989], requires_grad=True)
# Weights of synapse (0, 16): Main: Parameter containing:
# tensor([-1.0457], requires_grad=True)x^Parameter containing:
# tensor([0.9989], requires_grad=True)
# Weights of synapse (0, 17): Main: Parameter containing:
# tensor([-0.4301], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 18): Main: Parameter containing:
# tensor([0.3263], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 19): Main: Parameter containing:
# tensor([0.2948], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 20): Main: Parameter containing:
# tensor([-1.0345], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 21): Main: Parameter containing:
# tensor([0.0608], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 22): Main: Parameter containing:
# tensor([-0.4729], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 23): Main: Parameter containing:
# tensor([0.1232], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 24): Main: Parameter containing:
# tensor([-0.9783], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 25): Main: Parameter containing:
# tensor([-1.4186], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 26): Main: Parameter containing:
# tensor([-1.7559], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (0, 27): Main: Parameter containing:
# tensor([-0.8324], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 28): Main: Parameter containing:
# tensor([-0.4614], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 29): Main: Parameter containing:
# tensor([-0.1810], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 30): Main: Parameter containing:
# tensor([2.2506], requires_grad=True)x^Parameter containing:
# tensor([0.9986], requires_grad=True)
# Weights of synapse (0, 31): Main: Parameter containing:
# tensor([0.8577], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 32): Main: Parameter containing:
# tensor([0.5308], requires_grad=True)x^Parameter containing:
# tensor([1.0009], requires_grad=True)
# Weights of synapse (0, 33): Main: Parameter containing:
# tensor([-0.0956], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 34): Main: Parameter containing:
# tensor([0.6932], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 35): Main: Parameter containing:
# tensor([-1.6600], requires_grad=True)x^Parameter containing:
# tensor([0.9988], requires_grad=True)
# Weights of synapse (0, 36): Main: Parameter containing:
# tensor([-1.4727], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (0, 37): Main: Parameter containing:
# tensor([1.2744], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (0, 38): Main: Parameter containing:
# tensor([-1.1039], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 39): Main: Parameter containing:
# tensor([-0.1158], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 40): Main: Parameter containing:
# tensor([1.7813], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 41): Main: Parameter containing:
# tensor([0.1223], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 42): Main: Parameter containing:
# tensor([-0.3949], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 43): Main: Parameter containing:
# tensor([1.0521], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 44): Main: Parameter containing:
# tensor([-0.5531], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 45): Main: Parameter containing:
# tensor([0.7315], requires_grad=True)x^Parameter containing:
# tensor([1.0007], requires_grad=True)
# Weights of synapse (0, 46): Main: Parameter containing:
# tensor([1.9924], requires_grad=True)x^Parameter containing:
# tensor([0.9994], requires_grad=True)
# Weights of synapse (0, 47): Main: Parameter containing:
# tensor([-0.4469], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 48): Main: Parameter containing:
# tensor([1.7481], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 49): Main: Parameter containing:
# tensor([-2.0657], requires_grad=True)x^Parameter containing:
# tensor([0.9968], requires_grad=True)
# Weights of synapse (0, 50): Main: Parameter containing:
# tensor([-0.6048], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 51): Main: Parameter containing:
# tensor([-0.3300], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 52): Main: Parameter containing:
# tensor([0.2464], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 53): Main: Parameter containing:
# tensor([0.8808], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 54): Main: Parameter containing:
# tensor([-0.3341], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 55): Main: Parameter containing:
# tensor([-1.0313], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 56): Main: Parameter containing:
# tensor([1.1727], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 57): Main: Parameter containing:
# tensor([-0.3816], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 58): Main: Parameter containing:
# tensor([-0.0442], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 59): Main: Parameter containing:
# tensor([-0.4013], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 60): Main: Parameter containing:
# tensor([-0.9965], requires_grad=True)x^Parameter containing:
# tensor([0.9989], requires_grad=True)
# Weights of synapse (0, 61): Main: Parameter containing:
# tensor([-0.0781], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 62): Main: Parameter containing:
# tensor([0.8732], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 63): Main: Parameter containing:
# tensor([0.0476], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 64): Main: Parameter containing:
# tensor([1.8302], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 65): Main: Parameter containing:
# tensor([0.4634], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 66): Main: Parameter containing:
# tensor([0.7845], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 67): Main: Parameter containing:
# tensor([-0.3438], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 68): Main: Parameter containing:
# tensor([-0.2618], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 69): Main: Parameter containing:
# tensor([1.5349], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 70): Main: Parameter containing:
# tensor([1.6581], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (0, 71): Main: Parameter containing:
# tensor([2.0677], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 72): Main: Parameter containing:
# tensor([0.5509], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 73): Main: Parameter containing:
# tensor([0.8799], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 74): Main: Parameter containing:
# tensor([-0.6905], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 75): Main: Parameter containing:
# tensor([-0.0890], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 76): Main: Parameter containing:
# tensor([-0.4412], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 77): Main: Parameter containing:
# tensor([-0.1166], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 78): Main: Parameter containing:
# tensor([-0.8919], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 79): Main: Parameter containing:
# tensor([-0.1173], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 80): Main: Parameter containing:
# tensor([-0.2475], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 81): Main: Parameter containing:
# tensor([0.9097], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 82): Main: Parameter containing:
# tensor([-0.6583], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 83): Main: Parameter containing:
# tensor([1.5525], requires_grad=True)x^Parameter containing:
# tensor([1.0013], requires_grad=True)
# Weights of synapse (0, 84): Main: Parameter containing:
# tensor([2.0029], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 85): Main: Parameter containing:
# tensor([-0.5964], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 86): Main: Parameter containing:
# tensor([1.5517], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 87): Main: Parameter containing:
# tensor([1.5874], requires_grad=True)x^Parameter containing:
# tensor([1.0010], requires_grad=True)
# Weights of synapse (0, 88): Main: Parameter containing:
# tensor([0.6931], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 89): Main: Parameter containing:
# tensor([-1.4713], requires_grad=True)x^Parameter containing:
# tensor([0.9994], requires_grad=True)
# Weights of synapse (0, 90): Main: Parameter containing:
# tensor([-0.1338], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 91): Main: Parameter containing:
# tensor([-0.1768], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 92): Main: Parameter containing:
# tensor([-1.0448], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 93): Main: Parameter containing:
# tensor([-0.2202], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 94): Main: Parameter containing:
# tensor([0.3650], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 95): Main: Parameter containing:
# tensor([0.2099], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 96): Main: Parameter containing:
# tensor([0.0242], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 97): Main: Parameter containing:
# tensor([0.7165], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 98): Main: Parameter containing:
# tensor([-1.7382], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 99): Main: Parameter containing:
# tensor([1.1126], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 100): Main: Parameter containing:
# tensor([0.4096], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 101): Main: Parameter containing:
# tensor([-1.6050], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 102): Main: Parameter containing:
# tensor([-0.0197], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 103): Main: Parameter containing:
# tensor([0.8814], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (0, 104): Main: Parameter containing:
# tensor([-0.1772], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 105): Main: Parameter containing:
# tensor([0.3408], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 106): Main: Parameter containing:
# tensor([1.5736], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (0, 107): Main: Parameter containing:
# tensor([-0.2162], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 108): Main: Parameter containing:
# tensor([-0.1238], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 109): Main: Parameter containing:
# tensor([1.3976], requires_grad=True)x^Parameter containing:
# tensor([1.0026], requires_grad=True)
# Weights of synapse (0, 110): Main: Parameter containing:
# tensor([0.5024], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 111): Main: Parameter containing:
# tensor([0.7964], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 112): Main: Parameter containing:
# tensor([0.6632], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 113): Main: Parameter containing:
# tensor([-1.3852], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 114): Main: Parameter containing:
# tensor([-0.6446], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 115): Main: Parameter containing:
# tensor([0.3093], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 116): Main: Parameter containing:
# tensor([-0.9572], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 117): Main: Parameter containing:
# tensor([2.8775], requires_grad=True)x^Parameter containing:
# tensor([1.0008], requires_grad=True)
# Weights of synapse (0, 118): Main: Parameter containing:
# tensor([-0.1170], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 119): Main: Parameter containing:
# tensor([1.1764], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 120): Main: Parameter containing:
# tensor([-0.7166], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 121): Main: Parameter containing:
# tensor([-1.5143], requires_grad=True)x^Parameter containing:
# tensor([0.9985], requires_grad=True)
# Weights of synapse (0, 122): Main: Parameter containing:
# tensor([-0.9312], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 123): Main: Parameter containing:
# tensor([-0.9885], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 124): Main: Parameter containing:
# tensor([-0.4839], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 125): Main: Parameter containing:
# tensor([0.3097], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 126): Main: Parameter containing:
# tensor([0.2899], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 127): Main: Parameter containing:
# tensor([1.0160], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 128): Main: Parameter containing:
# tensor([-1.5425], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 129): Main: Parameter containing:
# tensor([0.1980], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 130): Main: Parameter containing:
# tensor([0.3223], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 131): Main: Parameter containing:
# tensor([-1.5915], requires_grad=True)x^Parameter containing:
# tensor([0.9990], requires_grad=True)
# Weights of synapse (0, 132): Main: Parameter containing:
# tensor([-0.2694], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 133): Main: Parameter containing:
# tensor([-1.3208], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (0, 134): Main: Parameter containing:
# tensor([-0.0135], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 135): Main: Parameter containing:
# tensor([1.6930], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 136): Main: Parameter containing:
# tensor([0.2784], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 137): Main: Parameter containing:
# tensor([1.0313], requires_grad=True)x^Parameter containing:
# tensor([1.0008], requires_grad=True)
# Weights of synapse (0, 138): Main: Parameter containing:
# tensor([-1.3903], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (0, 139): Main: Parameter containing:
# tensor([-0.4113], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 140): Main: Parameter containing:
# tensor([0.2959], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 141): Main: Parameter containing:
# tensor([0.4369], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 142): Main: Parameter containing:
# tensor([0.2304], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 143): Main: Parameter containing:
# tensor([-0.3684], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 144): Main: Parameter containing:
# tensor([0.9627], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 145): Main: Parameter containing:
# tensor([0.0772], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 146): Main: Parameter containing:
# tensor([-1.9978], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 147): Main: Parameter containing:
# tensor([0.0596], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 148): Main: Parameter containing:
# tensor([-0.9940], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 149): Main: Parameter containing:
# tensor([-0.3512], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 150): Main: Parameter containing:
# tensor([1.0957], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 151): Main: Parameter containing:
# tensor([0.8372], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 152): Main: Parameter containing:
# tensor([-0.3413], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 153): Main: Parameter containing:
# tensor([0.2594], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 154): Main: Parameter containing:
# tensor([-1.9946], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 155): Main: Parameter containing:
# tensor([0.3149], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 156): Main: Parameter containing:
# tensor([-0.6787], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 157): Main: Parameter containing:
# tensor([-1.0555], requires_grad=True)x^Parameter containing:
# tensor([0.9988], requires_grad=True)
# Weights of synapse (0, 158): Main: Parameter containing:
# tensor([0.3397], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 159): Main: Parameter containing:
# tensor([-1.6860], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 160): Main: Parameter containing:
# tensor([-0.5024], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 161): Main: Parameter containing:
# tensor([-1.2349], requires_grad=True)x^Parameter containing:
# tensor([0.9991], requires_grad=True)
# Weights of synapse (0, 162): Main: Parameter containing:
# tensor([0.0214], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 163): Main: Parameter containing:
# tensor([-0.9607], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 164): Main: Parameter containing:
# tensor([0.2122], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 165): Main: Parameter containing:
# tensor([0.1444], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 166): Main: Parameter containing:
# tensor([-0.6231], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 167): Main: Parameter containing:
# tensor([0.5929], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 168): Main: Parameter containing:
# tensor([0.2994], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 169): Main: Parameter containing:
# tensor([-2.9439], requires_grad=True)x^Parameter containing:
# tensor([0.9994], requires_grad=True)
# Weights of synapse (0, 170): Main: Parameter containing:
# tensor([0.2925], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 171): Main: Parameter containing:
# tensor([0.1388], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 172): Main: Parameter containing:
# tensor([0.7640], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 173): Main: Parameter containing:
# tensor([0.9164], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 174): Main: Parameter containing:
# tensor([-0.7453], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 175): Main: Parameter containing:
# tensor([0.8463], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 176): Main: Parameter containing:
# tensor([1.1435], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 177): Main: Parameter containing:
# tensor([-1.1374], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 178): Main: Parameter containing:
# tensor([-3.0371], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 179): Main: Parameter containing:
# tensor([-1.1361], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 180): Main: Parameter containing:
# tensor([-1.0959], requires_grad=True)x^Parameter containing:
# tensor([0.9988], requires_grad=True)
# Weights of synapse (0, 181): Main: Parameter containing:
# tensor([-0.1838], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 182): Main: Parameter containing:
# tensor([1.9255], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 183): Main: Parameter containing:
# tensor([0.3094], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 184): Main: Parameter containing:
# tensor([0.5156], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (0, 185): Main: Parameter containing:
# tensor([-0.7730], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 186): Main: Parameter containing:
# tensor([0.3856], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 187): Main: Parameter containing:
# tensor([-0.0906], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 188): Main: Parameter containing:
# tensor([0.2653], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 189): Main: Parameter containing:
# tensor([-0.2600], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 190): Main: Parameter containing:
# tensor([-0.6383], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 191): Main: Parameter containing:
# tensor([0.2775], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 192): Main: Parameter containing:
# tensor([-0.6512], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (0, 193): Main: Parameter containing:
# tensor([1.0395], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 194): Main: Parameter containing:
# tensor([0.3252], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 195): Main: Parameter containing:
# tensor([0.1149], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 196): Main: Parameter containing:
# tensor([-0.8153], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 197): Main: Parameter containing:
# tensor([0.7087], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 198): Main: Parameter containing:
# tensor([1.7133], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (0, 199): Main: Parameter containing:
# tensor([-1.0873], requires_grad=True)x^Parameter containing:
# tensor([0.9980], requires_grad=True)
# Weights of synapse (0, 200): Main: Parameter containing:
# tensor([0.5930], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 201): Main: Parameter containing:
# tensor([-0.0029], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 202): Main: Parameter containing:
# tensor([0.7141], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 203): Main: Parameter containing:
# tensor([-1.8808], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 204): Main: Parameter containing:
# tensor([-0.2394], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 205): Main: Parameter containing:
# tensor([1.4932], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (0, 206): Main: Parameter containing:
# tensor([0.5353], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 207): Main: Parameter containing:
# tensor([1.6330], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 208): Main: Parameter containing:
# tensor([-0.4069], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 209): Main: Parameter containing:
# tensor([0.7068], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (0, 210): Main: Parameter containing:
# tensor([0.3190], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 211): Main: Parameter containing:
# tensor([2.2438], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 212): Main: Parameter containing:
# tensor([-0.0731], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 213): Main: Parameter containing:
# tensor([-1.5784], requires_grad=True)x^Parameter containing:
# tensor([0.9981], requires_grad=True)
# Weights of synapse (0, 214): Main: Parameter containing:
# tensor([0.6779], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 215): Main: Parameter containing:
# tensor([1.1386], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 216): Main: Parameter containing:
# tensor([0.6631], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 217): Main: Parameter containing:
# tensor([1.8100], requires_grad=True)x^Parameter containing:
# tensor([1.0020], requires_grad=True)
# Weights of synapse (0, 218): Main: Parameter containing:
# tensor([0.2331], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 219): Main: Parameter containing:
# tensor([1.9770], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 220): Main: Parameter containing:
# tensor([-2.3564], requires_grad=True)x^Parameter containing:
# tensor([0.9981], requires_grad=True)
# Weights of synapse (0, 221): Main: Parameter containing:
# tensor([-0.3396], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 222): Main: Parameter containing:
# tensor([-0.2671], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 223): Main: Parameter containing:
# tensor([-0.6727], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (0, 224): Main: Parameter containing:
# tensor([-0.1773], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (0, 225): Main: Parameter containing:
# tensor([0.4536], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 226): Main: Parameter containing:
# tensor([-1.1075], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (0, 227): Main: Parameter containing:
# tensor([0.3997], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 228): Main: Parameter containing:
# tensor([0.3848], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 229): Main: Parameter containing:
# tensor([1.2361], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 230): Main: Parameter containing:
# tensor([0.5543], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 231): Main: Parameter containing:
# tensor([-0.7772], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 232): Main: Parameter containing:
# tensor([-0.0295], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 233): Main: Parameter containing:
# tensor([-0.1531], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 234): Main: Parameter containing:
# tensor([-0.5579], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 235): Main: Parameter containing:
# tensor([1.7193], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 236): Main: Parameter containing:
# tensor([0.3463], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (0, 237): Main: Parameter containing:
# tensor([0.4250], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 238): Main: Parameter containing:
# tensor([-1.1376], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 239): Main: Parameter containing:
# tensor([0.6774], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (0, 240): Main: Parameter containing:
# tensor([-1.5539], requires_grad=True)x^Parameter containing:
# tensor([0.9994], requires_grad=True)
# Weights of synapse (0, 241): Main: Parameter containing:
# tensor([0.2906], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 242): Main: Parameter containing:
# tensor([1.1854], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (0, 243): Main: Parameter containing:
# tensor([-1.0927], requires_grad=True)x^Parameter containing:
# tensor([0.9984], requires_grad=True)
# Weights of synapse (0, 244): Main: Parameter containing:
# tensor([-0.6262], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 245): Main: Parameter containing:
# tensor([-0.0700], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (0, 246): Main: Parameter containing:
# tensor([0.9027], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (0, 247): Main: Parameter containing:
# tensor([-0.2998], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (0, 248): Main: Parameter containing:
# tensor([0.4629], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (0, 249): Main: Parameter containing:
# tensor([0.0229], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (0, 250): Main: Parameter containing:
# tensor([-0.8037], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (0, 251): Main: Parameter containing:
# tensor([-0.6808], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (1, 0): Main: Parameter containing:
# tensor([1.3811], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (1, 1): Main: Parameter containing:
# tensor([1.0483], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (1, 2): Main: Parameter containing:
# tensor([-0.5767], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 3): Main: Parameter containing:
# tensor([-1.4274], requires_grad=True)x^Parameter containing:
# tensor([0.9986], requires_grad=True)
# Weights of synapse (1, 4): Main: Parameter containing:
# tensor([0.9437], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 5): Main: Parameter containing:
# tensor([-0.3714], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 6): Main: Parameter containing:
# tensor([0.5585], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 7): Main: Parameter containing:
# tensor([1.1023], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (1, 8): Main: Parameter containing:
# tensor([0.2004], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 9): Main: Parameter containing:
# tensor([1.3942], requires_grad=True)x^Parameter containing:
# tensor([0.9988], requires_grad=True)
# Weights of synapse (1, 10): Main: Parameter containing:
# tensor([-0.8242], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (1, 11): Main: Parameter containing:
# tensor([0.8405], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 12): Main: Parameter containing:
# tensor([1.3823], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (1, 13): Main: Parameter containing:
# tensor([0.5032], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (1, 14): Main: Parameter containing:
# tensor([-0.3423], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (1, 15): Main: Parameter containing:
# tensor([0.3336], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (1, 16): Main: Parameter containing:
# tensor([-0.2135], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 17): Main: Parameter containing:
# tensor([-0.2034], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 18): Main: Parameter containing:
# tensor([-0.8806], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (1, 19): Main: Parameter containing:
# tensor([-0.7101], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (1, 20): Main: Parameter containing:
# tensor([1.0768], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (1, 21): Main: Parameter containing:
# tensor([-0.8946], requires_grad=True)x^Parameter containing:
# tensor([0.9982], requires_grad=True)
# Weights of synapse (1, 22): Main: Parameter containing:
# tensor([-0.2005], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (1, 23): Main: Parameter containing:
# tensor([0.0560], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 24): Main: Parameter containing:
# tensor([-1.1466], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 25): Main: Parameter containing:
# tensor([-0.4652], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (1, 26): Main: Parameter containing:
# tensor([1.8384], requires_grad=True)x^Parameter containing:
# tensor([0.9982], requires_grad=True)
# Weights of synapse (1, 27): Main: Parameter containing:
# tensor([0.4103], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (1, 28): Main: Parameter containing:
# tensor([0.8684], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (1, 29): Main: Parameter containing:
# tensor([-0.2238], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 30): Main: Parameter containing:
# tensor([0.3825], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (1, 31): Main: Parameter containing:
# tensor([-1.0306], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (1, 32): Main: Parameter containing:
# tensor([1.3683], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (1, 33): Main: Parameter containing:
# tensor([-1.2736], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (1, 34): Main: Parameter containing:
# tensor([0.0159], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 35): Main: Parameter containing:
# tensor([0.0275], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 36): Main: Parameter containing:
# tensor([-0.1423], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 37): Main: Parameter containing:
# tensor([0.4606], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 38): Main: Parameter containing:
# tensor([1.0821], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 39): Main: Parameter containing:
# tensor([0.3779], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 40): Main: Parameter containing:
# tensor([-0.1773], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 41): Main: Parameter containing:
# tensor([0.3451], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 42): Main: Parameter containing:
# tensor([0.8610], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 43): Main: Parameter containing:
# tensor([0.8379], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (1, 44): Main: Parameter containing:
# tensor([0.1193], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 45): Main: Parameter containing:
# tensor([-0.5203], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (1, 46): Main: Parameter containing:
# tensor([0.3653], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (1, 47): Main: Parameter containing:
# tensor([-0.6041], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (1, 48): Main: Parameter containing:
# tensor([0.9998], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (1, 49): Main: Parameter containing:
# tensor([-0.5477], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 50): Main: Parameter containing:
# tensor([-0.1161], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (1, 51): Main: Parameter containing:
# tensor([-0.2701], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (1, 52): Main: Parameter containing:
# tensor([-0.5266], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 53): Main: Parameter containing:
# tensor([-0.9290], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 54): Main: Parameter containing:
# tensor([0.7986], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (1, 55): Main: Parameter containing:
# tensor([0.2752], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (1, 56): Main: Parameter containing:
# tensor([1.3300], requires_grad=True)x^Parameter containing:
# tensor([0.9984], requires_grad=True)
# Weights of synapse (1, 57): Main: Parameter containing:
# tensor([0.5502], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (1, 58): Main: Parameter containing:
# tensor([-1.0428], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (1, 59): Main: Parameter containing:
# tensor([0.0669], requires_grad=True)x^Parameter containing:
# ...
# tensor([1.0003], requires_grad=True)
# Weights of synapse (9, 149): Main: Parameter containing:
# tensor([0.1022], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 150): Main: Parameter containing:
# tensor([0.8455], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 151): Main: Parameter containing:
# tensor([-0.6148], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (9, 152): Main: Parameter containing:
# tensor([-0.7298], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (9, 153): Main: Parameter containing:
# tensor([-0.8741], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 154): Main: Parameter containing:
# tensor([1.2066], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (9, 155): Main: Parameter containing:
# tensor([-0.6089], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 156): Main: Parameter containing:
# tensor([0.5743], requires_grad=True)x^Parameter containing:
# tensor([1.0008], requires_grad=True)
# Weights of synapse (9, 157): Main: Parameter containing:
# tensor([1.3726], requires_grad=True)x^Parameter containing:
# tensor([1.0008], requires_grad=True)
# Weights of synapse (9, 158): Main: Parameter containing:
# tensor([-0.5943], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (9, 159): Main: Parameter containing:
# tensor([0.2876], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 160): Main: Parameter containing:
# tensor([1.1911], requires_grad=True)x^Parameter containing:
# tensor([1.0015], requires_grad=True)
# Weights of synapse (9, 161): Main: Parameter containing:
# tensor([-0.8967], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 162): Main: Parameter containing:
# tensor([-0.4260], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 163): Main: Parameter containing:
# tensor([0.2027], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 164): Main: Parameter containing:
# tensor([-0.0702], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 165): Main: Parameter containing:
# tensor([1.6455], requires_grad=True)x^Parameter containing:
# tensor([1.0029], requires_grad=True)
# Weights of synapse (9, 166): Main: Parameter containing:
# tensor([0.0734], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 167): Main: Parameter containing:
# tensor([0.3298], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 168): Main: Parameter containing:
# tensor([0.2104], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 169): Main: Parameter containing:
# tensor([-1.4766], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 170): Main: Parameter containing:
# tensor([-0.5145], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (9, 171): Main: Parameter containing:
# tensor([0.1818], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 172): Main: Parameter containing:
# tensor([0.2991], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 173): Main: Parameter containing:
# tensor([1.4231], requires_grad=True)x^Parameter containing:
# tensor([1.0007], requires_grad=True)
# Weights of synapse (9, 174): Main: Parameter containing:
# tensor([0.3115], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 175): Main: Parameter containing:
# tensor([0.7894], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 176): Main: Parameter containing:
# tensor([-2.2848], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 177): Main: Parameter containing:
# tensor([0.3149], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (9, 178): Main: Parameter containing:
# tensor([1.5417], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 179): Main: Parameter containing:
# tensor([0.6493], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (9, 180): Main: Parameter containing:
# tensor([-0.7245], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (9, 181): Main: Parameter containing:
# tensor([-0.3509], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 182): Main: Parameter containing:
# tensor([0.7794], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (9, 183): Main: Parameter containing:
# tensor([0.7375], requires_grad=True)x^Parameter containing:
# tensor([1.0008], requires_grad=True)
# Weights of synapse (9, 184): Main: Parameter containing:
# tensor([-2.3808], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (9, 185): Main: Parameter containing:
# tensor([1.2591], requires_grad=True)x^Parameter containing:
# tensor([0.9978], requires_grad=True)
# Weights of synapse (9, 186): Main: Parameter containing:
# tensor([-2.0574], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (9, 187): Main: Parameter containing:
# tensor([0.6377], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (9, 188): Main: Parameter containing:
# tensor([0.3993], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 189): Main: Parameter containing:
# tensor([0.5906], requires_grad=True)x^Parameter containing:
# tensor([0.9996], requires_grad=True)
# Weights of synapse (9, 190): Main: Parameter containing:
# tensor([0.4970], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (9, 191): Main: Parameter containing:
# tensor([1.2251], requires_grad=True)x^Parameter containing:
# tensor([0.9990], requires_grad=True)
# Weights of synapse (9, 192): Main: Parameter containing:
# tensor([-0.7916], requires_grad=True)x^Parameter containing:
# tensor([0.9990], requires_grad=True)
# Weights of synapse (9, 193): Main: Parameter containing:
# tensor([2.1623], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (9, 194): Main: Parameter containing:
# tensor([-0.1127], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 195): Main: Parameter containing:
# tensor([-1.4649], requires_grad=True)x^Parameter containing:
# tensor([0.9987], requires_grad=True)
# Weights of synapse (9, 196): Main: Parameter containing:
# tensor([0.0438], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 197): Main: Parameter containing:
# tensor([-0.3324], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 198): Main: Parameter containing:
# tensor([0.2236], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 199): Main: Parameter containing:
# tensor([-0.4471], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (9, 200): Main: Parameter containing:
# tensor([-0.4429], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (9, 201): Main: Parameter containing:
# tensor([-0.2703], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 202): Main: Parameter containing:
# tensor([-0.3085], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (9, 203): Main: Parameter containing:
# tensor([-0.4088], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (9, 204): Main: Parameter containing:
# tensor([0.5100], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 205): Main: Parameter containing:
# tensor([0.7504], requires_grad=True)x^Parameter containing:
# tensor([1.0009], requires_grad=True)
# Weights of synapse (9, 206): Main: Parameter containing:
# tensor([0.5394], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (9, 207): Main: Parameter containing:
# tensor([0.2151], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 208): Main: Parameter containing:
# tensor([0.1259], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 209): Main: Parameter containing:
# tensor([1.0207], requires_grad=True)x^Parameter containing:
# tensor([1.0003], requires_grad=True)
# Weights of synapse (9, 210): Main: Parameter containing:
# tensor([-0.8022], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 211): Main: Parameter containing:
# tensor([-0.2317], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 212): Main: Parameter containing:
# tensor([-1.2613], requires_grad=True)x^Parameter containing:
# tensor([0.9991], requires_grad=True)
# Weights of synapse (9, 213): Main: Parameter containing:
# tensor([0.7063], requires_grad=True)x^Parameter containing:
# tensor([1.0005], requires_grad=True)
# Weights of synapse (9, 214): Main: Parameter containing:
# tensor([-0.4822], requires_grad=True)x^Parameter containing:
# tensor([0.9992], requires_grad=True)
# Weights of synapse (9, 215): Main: Parameter containing:
# tensor([1.3566], requires_grad=True)x^Parameter containing:
# tensor([1.0018], requires_grad=True)
# Weights of synapse (9, 216): Main: Parameter containing:
# tensor([-1.7449], requires_grad=True)x^Parameter containing:
# tensor([0.9978], requires_grad=True)
# Weights of synapse (9, 217): Main: Parameter containing:
# tensor([0.0001], requires_grad=True)x^Parameter containing:
# tensor([1.], requires_grad=True)
# Weights of synapse (9, 218): Main: Parameter containing:
# tensor([-1.3000], requires_grad=True)x^Parameter containing:
# tensor([0.9993], requires_grad=True)
# Weights of synapse (9, 219): Main: Parameter containing:
# tensor([-1.7141], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 220): Main: Parameter containing:
# tensor([-0.2500], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 221): Main: Parameter containing:
# tensor([-0.3519], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 222): Main: Parameter containing:
# tensor([-0.7411], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 223): Main: Parameter containing:
# tensor([0.6328], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (9, 224): Main: Parameter containing:
# tensor([-0.7237], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 225): Main: Parameter containing:
# tensor([-0.9225], requires_grad=True)x^Parameter containing:
# tensor([0.9991], requires_grad=True)
# Weights of synapse (9, 226): Main: Parameter containing:
# tensor([0.0369], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 227): Main: Parameter containing:
# tensor([0.4838], requires_grad=True)x^Parameter containing:
# tensor([0.9994], requires_grad=True)
# Weights of synapse (9, 228): Main: Parameter containing:
# tensor([-0.4899], requires_grad=True)x^Parameter containing:
# tensor([0.9997], requires_grad=True)
# Weights of synapse (9, 229): Main: Parameter containing:
# tensor([-1.8172], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 230): Main: Parameter containing:
# tensor([0.8370], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 231): Main: Parameter containing:
# tensor([-0.2678], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 232): Main: Parameter containing:
# tensor([1.3946], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 233): Main: Parameter containing:
# tensor([-0.7990], requires_grad=True)x^Parameter containing:
# tensor([1.0004], requires_grad=True)
# Weights of synapse (9, 234): Main: Parameter containing:
# tensor([0.3111], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (9, 235): Main: Parameter containing:
# tensor([-1.5147], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 236): Main: Parameter containing:
# tensor([-0.2323], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 237): Main: Parameter containing:
# tensor([6.1610e-05], requires_grad=True)x^Parameter containing:
# tensor([1.], requires_grad=True)
# Weights of synapse (9, 238): Main: Parameter containing:
# tensor([0.1743], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 239): Main: Parameter containing:
# tensor([-0.4683], requires_grad=True)x^Parameter containing:
# tensor([0.9995], requires_grad=True)
# Weights of synapse (9, 240): Main: Parameter containing:
# tensor([-0.3402], requires_grad=True)x^Parameter containing:
# tensor([1.0002], requires_grad=True)
# Weights of synapse (9, 241): Main: Parameter containing:
# tensor([0.9358], requires_grad=True)x^Parameter containing:
# tensor([1.0006], requires_grad=True)
# Weights of synapse (9, 242): Main: Parameter containing:
# tensor([0.0722], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 243): Main: Parameter containing:
# tensor([-0.1813], requires_grad=True)x^Parameter containing:
# tensor([0.9999], requires_grad=True)
# Weights of synapse (9, 244): Main: Parameter containing:
# tensor([0.2791], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 245): Main: Parameter containing:
# tensor([-1.0905], requires_grad=True)x^Parameter containing:
# tensor([0.9988], requires_grad=True)
# Weights of synapse (9, 246): Main: Parameter containing:
# tensor([2.1311], requires_grad=True)x^Parameter containing:
# tensor([0.9978], requires_grad=True)
# Weights of synapse (9, 247): Main: Parameter containing:
# tensor([-0.2005], requires_grad=True)x^Parameter containing:
# tensor([0.9998], requires_grad=True)
# Weights of synapse (9, 248): Main: Parameter containing:
# tensor([0.3190], requires_grad=True)x^Parameter containing:
# tensor([1.0000], requires_grad=True)
# Weights of synapse (9, 249): Main: Parameter containing:
# tensor([0.2452], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)
# Weights of synapse (9, 250): Main: Parameter containing:
# tensor([-1.6144], requires_grad=True)x^Parameter containing:
# tensor([0.9984], requires_grad=True)
# Weights of synapse (9, 251): Main: Parameter containing:
# tensor([-0.6982], requires_grad=True)x^Parameter containing:
# tensor([1.0001], requires_grad=True)

# %%
# TODO: report test performance of best model

test_acc = test('best_model.pth', test_loader)
print(test_acc)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 3
#       1 # TODO: report test performance of best model
# ----> 3 test_acc = test('best_model.pth', test_loader)
#       4 print(test_acc)
#
# Cell In[19], line 5, in test(model_path, test_loader)
#       1 def test(model_path, test_loader):
#       2   # TODO: test function for your trained model, load your best model
#       3   # use the provided test loader
#       4   # return the test accuracy
# ----> 5   model = torch.load(model_path)
#       6   model.eval()
#       7   with torch.no_grad():
#
# File ~/anaconda3/envs/mlenv/lib/python3.11/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/mlenv/lib/python3.11/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File ~/anaconda3/envs/mlenv/lib/python3.11/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best_model.pth'
