# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms

from torch.nn import functional as F

import time
import math

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
def create_data_loader(batch_size):
  # Split the provided CIFAR-10 train set (50,000 images) into your train and val sets
  # Use the first 40,000 images as your train set and the remaining 10,000 images as val set
  # Use all 10,000 images in the provided test set as your test set

  transform = transforms.Compose([
    transforms.Resize((227, 227)),  # Resize the images to a larger size
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2470, 0.2435, 0.2616)), 
  ])

  # load cifar
  train_set = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
  test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

  # split train set into train and val
  train_set, val_set = torch.utils.data.random_split(train_set, [40000, 10000])

  # create data loaders
  train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True,num_workers=4)
  val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=True,num_workers=4)
  test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True,num_workers=4)

  train_loader = [(inputs.to(device), labels.to(device)) for inputs, labels in train_loader]
  val_loader = [(inputs.to(device), labels.to(device)) for inputs, labels in val_loader]
  test_loader = [(inputs.to(device), labels.to(device)) for inputs, labels in test_loader]


  return train_loader, val_loader, test_loader

# %%
class QuasiPolySynapse(nn.Module):
    def __init__(self):
        super().__init__() 
        # 50% chance of being 1 and 50% change of being 2
        power_initial_value = 1.0 if torch.rand(1) < 0.5 else 1.5
        self.main = nn.ParameterList([torch.randn(1),torch.tensor([power_initial_value],requires_grad=False)])
        # self.main = nn.ParameterList([torch.randn(1)])
        self.terms = nn.ParameterList()

        
    def forward(self, x):
        if  len(self.terms) < math.floor(self.main[1]) - 1:
            self.add_term()
        y = self.main[0] * x ** self.main[1]
        for idx,coeff in enumerate(self.terms):
             y = y + coeff * x**(idx+1)
        return y

    def add_term(self):
        print("Adding term")
        # Add new term, init coeff to 1. non-trainable exponent to floor of main exponent
        self.terms.append(nn.Parameter(torch.tensor([1.])))

    def __str__(self):
        s = ""
        s += f"Main: {self.main[0]}x^{self.main[1]} + "
        for idx,term in enumerate(self.terms):
            s += f"{term}x^{idx+1} + "
        return s[:-3]



class QuasiPolyLayer(nn.Module):
  def __init__(self, in_features, out_features, product=False):
    super().__init__()
    self.out_features = out_features
    self.in_features = in_features
    # a 2d module list of quasipoly synapses sizes in_features x out_features
    self.synapses = nn.ModuleList([nn.ModuleList([QuasiPolySynapse() for _ in range(self.in_features)]) for _ in range(self.out_features)])
    self.bias = nn.Parameter(torch.randn(out_features))
    self.product = product
  
  def forward(self, x): # x is a batch of inputs

    y = torch.zeros(x.shape[0], self.out_features, dtype=torch.float32)

    # move to device
    y = y.to(device)

    # print if synapses are on device
    # for i in range(self.out_features):
    #     for j in range(self.in_features):
    #         print(f"synapse {i} {j} on device {self.synapses[i][j].to(device)}")

    # print(f"input of quasipoly layer {x}")
    
    # apply synapses to inputs
    for i in range(self.out_features):
        if self.product:
            y[:, i] = 1
        else:
            y[:, i] = 0
    
        for j in range(self.in_features):
            if self.product:
                y[:, i] = y[:, i] * self.synapses[i][j](x[:, j])
            else:
                y[:, i] = y[:, i] + self.synapses[i][j](x[:, j])

    # add bias
    y = y + self.bias

    return y
  


class AddEpsilon(nn.Module):
    def __init__(self, epsilon=1e-10): # 1e-10 is smallest possible float in pytorch
        super().__init__()
        self.epsilon = epsilon

    def forward(self, x):
        return x + self.epsilon

# %%
def init_train_var(model):
  
  criterion = nn.CrossEntropyLoss()
  optimizer = torch.optim.SGD(model.parameters(), lr=0.005, momentum=0.2,weight_decay=0.0001) # set momentum to 0.2 after trial and error
  # optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=0.00001)
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

  return criterion, optimizer

# %%
def test(model_path, test_loader):
  # use the provided test loader
  # return the test accuracy
  model = torch.load(model_path)
  model.eval()
  with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
      outputs = model(images)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()
    test_acc = correct / total
  return test_acc

# %%
BATCH_SIZE = 64
train_loader, val_loader, test_loader = create_data_loader(batch_size=BATCH_SIZE)

# use the alexnet model
model = torchvision.models.alexnet(pretrained=False)

# # replace the fully connected layer with quasipoly layer
model.classifier[6] = QuasiPolyLayer(in_features=4096, out_features=10)

model = model.to(device)
# model = nn.DataParallel(model)
criterion, optimizer = init_train_var(model)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# print model architecture
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): QuasiPolyLayer(
#       (synapses): ModuleList(
#         (0-9): 10 x ModuleList(
#           (0-4095): 4096 x QuasiPolySynapse(
#             (main): ParameterList(
#                 (0): Parameter containing: [torch.float32 of size 1 (cuda:0)]
#                 (1): Parameter containing: [torch.float32 of size 1 (cuda:0)]
#             )
#             (terms): ParameterList()
#           )
#         )
#       )
#     )
#   )
# )

# %%
EPOCH_COUNT = 100

# %%
# %%time

for epoch in range(EPOCH_COUNT):
    model.train()
    train_loss = 0
    train_correct = 0
    # for each batch
    for i, (inputs, labels) in enumerate(train_loader):
        # count the number of weights with very small magnitute < 1e-3
        # nans_count = 0
        # for param in model.parameters():
        #     if param.grad is not None:
        #         nans_count += torch.sum(torch.isnan(param.grad)).item()
        
        # print(f"nans count: {nans_count}")
        
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        # print all gradients of the first synapse
        # print(f"synapse grads : {model.classifier[-1].synapses[0][0].main[0].grad}")
        # print(f"weights of first layer {model.classifier[-1].synapses[0][0]}")
        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        train_correct += (predicted == labels).sum().item()


    print(f'Epoch {epoch+1}/{EPOCH_COUNT}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_correct/40000:.4f}')
    # validate
    model.eval()
    val_loss = 0
    val_correct = 0
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_loader):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels).sum().item()
    val_acc = val_correct/10000
    print(f'Epoch {epoch+1}/{EPOCH_COUNT}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.4f}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:20
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /usr/local/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
# print weights of quasi poly layer

quasi_poly_layer = model.module.classifier[-1]
for i in range(quasi_poly_layer.out_features):
    for j in range(quasi_poly_layer.in_features):
        synapse = quasi_poly_layer.synapses[i][j]
        print(f"Weights of synapse ({i}, {j}): {synapse}")
# Out:
# Weights of synapse (0, 0): Main: Parameter containing:
# tensor([3.5350], requires_grad=True)x^Parameter containing:
# tensor([0.9736], requires_grad=True)
# Weights of synapse (0, 1): Main: Parameter containing:
# tensor([-0.3921], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (0, 2): Main: Parameter containing:
# tensor([0.7600], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 3): Main: Parameter containing:
# tensor([2.3518], requires_grad=True)x^Parameter containing:
# tensor([0.9796], requires_grad=True)
# Weights of synapse (0, 4): Main: Parameter containing:
# tensor([1.5484], requires_grad=True)x^Parameter containing:
# tensor([1.4898], requires_grad=True)
# Weights of synapse (0, 5): Main: Parameter containing:
# tensor([-1.9674], requires_grad=True)x^Parameter containing:
# tensor([1.4968], requires_grad=True)
# Weights of synapse (0, 6): Main: Parameter containing:
# tensor([1.6850], requires_grad=True)x^Parameter containing:
# tensor([1.4917], requires_grad=True)
# Weights of synapse (0, 7): Main: Parameter containing:
# tensor([-1.0053], requires_grad=True)x^Parameter containing:
# tensor([1.4920], requires_grad=True)
# Weights of synapse (0, 8): Main: Parameter containing:
# tensor([0.5991], requires_grad=True)x^Parameter containing:
# tensor([1.4934], requires_grad=True)
# Weights of synapse (0, 9): Main: Parameter containing:
# tensor([-0.7907], requires_grad=True)x^Parameter containing:
# tensor([1.4923], requires_grad=True)
# Weights of synapse (0, 10): Main: Parameter containing:
# tensor([-0.9529], requires_grad=True)x^Parameter containing:
# tensor([0.9905], requires_grad=True)
# Weights of synapse (0, 11): Main: Parameter containing:
# tensor([1.4392], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 12): Main: Parameter containing:
# tensor([1.0920], requires_grad=True)x^Parameter containing:
# tensor([0.9934], requires_grad=True)
# Weights of synapse (0, 13): Main: Parameter containing:
# tensor([-1.7510], requires_grad=True)x^Parameter containing:
# tensor([0.9844], requires_grad=True)
# Weights of synapse (0, 14): Main: Parameter containing:
# tensor([-0.5913], requires_grad=True)x^Parameter containing:
# tensor([1.4937], requires_grad=True)
# Weights of synapse (0, 15): Main: Parameter containing:
# tensor([-1.0651], requires_grad=True)x^Parameter containing:
# tensor([1.4951], requires_grad=True)
# Weights of synapse (0, 16): Main: Parameter containing:
# tensor([1.0396], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (0, 17): Main: Parameter containing:
# tensor([0.8111], requires_grad=True)x^Parameter containing:
# tensor([0.9912], requires_grad=True)
# Weights of synapse (0, 18): Main: Parameter containing:
# tensor([0.4494], requires_grad=True)x^Parameter containing:
# tensor([1.4918], requires_grad=True)
# Weights of synapse (0, 19): Main: Parameter containing:
# tensor([-0.8936], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 20): Main: Parameter containing:
# tensor([-1.0807], requires_grad=True)x^Parameter containing:
# tensor([1.4912], requires_grad=True)
# Weights of synapse (0, 21): Main: Parameter containing:
# tensor([-0.8112], requires_grad=True)x^Parameter containing:
# tensor([0.9934], requires_grad=True)
# Weights of synapse (0, 22): Main: Parameter containing:
# tensor([-1.2874], requires_grad=True)x^Parameter containing:
# tensor([1.4922], requires_grad=True)
# Weights of synapse (0, 23): Main: Parameter containing:
# tensor([-0.6545], requires_grad=True)x^Parameter containing:
# tensor([1.4917], requires_grad=True)
# Weights of synapse (0, 24): Main: Parameter containing:
# tensor([0.2653], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 25): Main: Parameter containing:
# tensor([0.5867], requires_grad=True)x^Parameter containing:
# tensor([0.9958], requires_grad=True)
# Weights of synapse (0, 26): Main: Parameter containing:
# tensor([-0.3370], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (0, 27): Main: Parameter containing:
# tensor([0.6650], requires_grad=True)x^Parameter containing:
# tensor([0.9948], requires_grad=True)
# Weights of synapse (0, 28): Main: Parameter containing:
# tensor([1.2168], requires_grad=True)x^Parameter containing:
# tensor([0.9970], requires_grad=True)
# Weights of synapse (0, 29): Main: Parameter containing:
# tensor([-0.4701], requires_grad=True)x^Parameter containing:
# tensor([0.9962], requires_grad=True)
# Weights of synapse (0, 30): Main: Parameter containing:
# tensor([0.1787], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 31): Main: Parameter containing:
# tensor([-0.2234], requires_grad=True)x^Parameter containing:
# tensor([0.9956], requires_grad=True)
# Weights of synapse (0, 32): Main: Parameter containing:
# tensor([0.5675], requires_grad=True)x^Parameter containing:
# tensor([1.4921], requires_grad=True)
# Weights of synapse (0, 33): Main: Parameter containing:
# tensor([0.9060], requires_grad=True)x^Parameter containing:
# tensor([1.4920], requires_grad=True)
# Weights of synapse (0, 34): Main: Parameter containing:
# tensor([0.8698], requires_grad=True)x^Parameter containing:
# tensor([1.4919], requires_grad=True)
# Weights of synapse (0, 35): Main: Parameter containing:
# tensor([0.1527], requires_grad=True)x^Parameter containing:
# tensor([0.9951], requires_grad=True)
# Weights of synapse (0, 36): Main: Parameter containing:
# tensor([0.3765], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 37): Main: Parameter containing:
# tensor([-1.4139], requires_grad=True)x^Parameter containing:
# tensor([0.9884], requires_grad=True)
# Weights of synapse (0, 38): Main: Parameter containing:
# tensor([-0.9175], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 39): Main: Parameter containing:
# tensor([0.6561], requires_grad=True)x^Parameter containing:
# tensor([0.9962], requires_grad=True)
# Weights of synapse (0, 40): Main: Parameter containing:
# tensor([-0.6379], requires_grad=True)x^Parameter containing:
# tensor([1.4938], requires_grad=True)
# Weights of synapse (0, 41): Main: Parameter containing:
# tensor([-1.5300], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 42): Main: Parameter containing:
# tensor([1.1164], requires_grad=True)x^Parameter containing:
# tensor([1.4953], requires_grad=True)
# Weights of synapse (0, 43): Main: Parameter containing:
# tensor([0.3538], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 44): Main: Parameter containing:
# tensor([-0.6523], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 45): Main: Parameter containing:
# tensor([1.2120], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 46): Main: Parameter containing:
# tensor([1.1354], requires_grad=True)x^Parameter containing:
# tensor([1.4885], requires_grad=True)
# Weights of synapse (0, 47): Main: Parameter containing:
# tensor([0.7966], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (0, 48): Main: Parameter containing:
# tensor([-0.4560], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (0, 49): Main: Parameter containing:
# tensor([0.1290], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 50): Main: Parameter containing:
# tensor([2.1270], requires_grad=True)x^Parameter containing:
# tensor([0.9811], requires_grad=True)
# Weights of synapse (0, 51): Main: Parameter containing:
# tensor([1.3360], requires_grad=True)x^Parameter containing:
# tensor([1.4938], requires_grad=True)
# Weights of synapse (0, 52): Main: Parameter containing:
# tensor([-0.6170], requires_grad=True)x^Parameter containing:
# tensor([1.4932], requires_grad=True)
# Weights of synapse (0, 53): Main: Parameter containing:
# tensor([-0.8997], requires_grad=True)x^Parameter containing:
# tensor([1.4939], requires_grad=True)
# Weights of synapse (0, 54): Main: Parameter containing:
# tensor([0.8516], requires_grad=True)x^Parameter containing:
# tensor([1.4935], requires_grad=True)
# Weights of synapse (0, 55): Main: Parameter containing:
# tensor([-0.1763], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (0, 56): Main: Parameter containing:
# tensor([0.9765], requires_grad=True)x^Parameter containing:
# tensor([0.9897], requires_grad=True)
# Weights of synapse (0, 57): Main: Parameter containing:
# tensor([-0.9489], requires_grad=True)x^Parameter containing:
# tensor([0.9946], requires_grad=True)
# Weights of synapse (0, 58): Main: Parameter containing:
# tensor([1.2319], requires_grad=True)x^Parameter containing:
# tensor([1.4903], requires_grad=True)
# Weights of synapse (0, 59): Main: Parameter containing:
# tensor([-1.0119], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (0, 60): Main: Parameter containing:
# tensor([0.1727], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 61): Main: Parameter containing:
# tensor([2.3957], requires_grad=True)x^Parameter containing:
# tensor([0.9838], requires_grad=True)
# Weights of synapse (0, 62): Main: Parameter containing:
# tensor([0.6611], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (0, 63): Main: Parameter containing:
# tensor([0.1075], requires_grad=True)x^Parameter containing:
# tensor([0.9949], requires_grad=True)
# Weights of synapse (0, 64): Main: Parameter containing:
# tensor([-0.2095], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (0, 65): Main: Parameter containing:
# tensor([1.2514], requires_grad=True)x^Parameter containing:
# tensor([1.4936], requires_grad=True)
# Weights of synapse (0, 66): Main: Parameter containing:
# tensor([1.5921], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (0, 67): Main: Parameter containing:
# tensor([1.7064], requires_grad=True)x^Parameter containing:
# tensor([1.4912], requires_grad=True)
# Weights of synapse (0, 68): Main: Parameter containing:
# tensor([-0.4363], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 69): Main: Parameter containing:
# tensor([1.1283], requires_grad=True)x^Parameter containing:
# tensor([0.9933], requires_grad=True)
# Weights of synapse (0, 70): Main: Parameter containing:
# tensor([0.8798], requires_grad=True)x^Parameter containing:
# tensor([0.9958], requires_grad=True)
# Weights of synapse (0, 71): Main: Parameter containing:
# tensor([0.5460], requires_grad=True)x^Parameter containing:
# tensor([0.9932], requires_grad=True)
# Weights of synapse (0, 72): Main: Parameter containing:
# tensor([-0.0246], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 73): Main: Parameter containing:
# tensor([0.1674], requires_grad=True)x^Parameter containing:
# tensor([0.9949], requires_grad=True)
# Weights of synapse (0, 74): Main: Parameter containing:
# tensor([0.8610], requires_grad=True)x^Parameter containing:
# tensor([0.9946], requires_grad=True)
# Weights of synapse (0, 75): Main: Parameter containing:
# tensor([0.3053], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (0, 76): Main: Parameter containing:
# tensor([-1.5807], requires_grad=True)x^Parameter containing:
# tensor([0.9860], requires_grad=True)
# Weights of synapse (0, 77): Main: Parameter containing:
# tensor([1.2709], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 78): Main: Parameter containing:
# tensor([0.5021], requires_grad=True)x^Parameter containing:
# tensor([1.4940], requires_grad=True)
# Weights of synapse (0, 79): Main: Parameter containing:
# tensor([0.1297], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 80): Main: Parameter containing:
# tensor([-0.3617], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 81): Main: Parameter containing:
# tensor([0.4254], requires_grad=True)x^Parameter containing:
# tensor([1.4941], requires_grad=True)
# Weights of synapse (0, 82): Main: Parameter containing:
# tensor([0.1231], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (0, 83): Main: Parameter containing:
# tensor([0.4109], requires_grad=True)x^Parameter containing:
# tensor([0.9947], requires_grad=True)
# Weights of synapse (0, 84): Main: Parameter containing:
# tensor([-1.8327], requires_grad=True)x^Parameter containing:
# tensor([0.9926], requires_grad=True)
# Weights of synapse (0, 85): Main: Parameter containing:
# tensor([-0.3965], requires_grad=True)x^Parameter containing:
# tensor([1.4938], requires_grad=True)
# Weights of synapse (0, 86): Main: Parameter containing:
# tensor([0.1683], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (0, 87): Main: Parameter containing:
# tensor([-1.4395], requires_grad=True)x^Parameter containing:
# tensor([1.4895], requires_grad=True)
# Weights of synapse (0, 88): Main: Parameter containing:
# tensor([-1.0145], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 89): Main: Parameter containing:
# tensor([-0.4251], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 90): Main: Parameter containing:
# tensor([0.5312], requires_grad=True)x^Parameter containing:
# tensor([0.9958], requires_grad=True)
# Weights of synapse (0, 91): Main: Parameter containing:
# tensor([1.2667], requires_grad=True)x^Parameter containing:
# tensor([0.9937], requires_grad=True)
# Weights of synapse (0, 92): Main: Parameter containing:
# tensor([0.4106], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 93): Main: Parameter containing:
# tensor([-0.5154], requires_grad=True)x^Parameter containing:
# tensor([0.9958], requires_grad=True)
# Weights of synapse (0, 94): Main: Parameter containing:
# tensor([0.8255], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 95): Main: Parameter containing:
# tensor([-0.3444], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 96): Main: Parameter containing:
# tensor([0.3113], requires_grad=True)x^Parameter containing:
# tensor([0.9949], requires_grad=True)
# Weights of synapse (0, 97): Main: Parameter containing:
# tensor([0.6405], requires_grad=True)x^Parameter containing:
# tensor([0.9966], requires_grad=True)
# Weights of synapse (0, 98): Main: Parameter containing:
# tensor([-0.7893], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (0, 99): Main: Parameter containing:
# tensor([0.5665], requires_grad=True)x^Parameter containing:
# tensor([0.9947], requires_grad=True)
# Weights of synapse (0, 100): Main: Parameter containing:
# tensor([-0.6213], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 101): Main: Parameter containing:
# tensor([-1.3390], requires_grad=True)x^Parameter containing:
# tensor([1.4913], requires_grad=True)
# Weights of synapse (0, 102): Main: Parameter containing:
# tensor([0.7432], requires_grad=True)x^Parameter containing:
# tensor([1.4937], requires_grad=True)
# Weights of synapse (0, 103): Main: Parameter containing:
# tensor([0.3341], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (0, 104): Main: Parameter containing:
# tensor([-2.0951], requires_grad=True)x^Parameter containing:
# tensor([1.4933], requires_grad=True)
# Weights of synapse (0, 105): Main: Parameter containing:
# tensor([-0.2735], requires_grad=True)x^Parameter containing:
# tensor([0.9947], requires_grad=True)
# Weights of synapse (0, 106): Main: Parameter containing:
# tensor([1.1123], requires_grad=True)x^Parameter containing:
# tensor([0.9848], requires_grad=True)
# Weights of synapse (0, 107): Main: Parameter containing:
# tensor([-0.8826], requires_grad=True)x^Parameter containing:
# tensor([0.9936], requires_grad=True)
# Weights of synapse (0, 108): Main: Parameter containing:
# tensor([0.3093], requires_grad=True)x^Parameter containing:
# tensor([1.4935], requires_grad=True)
# Weights of synapse (0, 109): Main: Parameter containing:
# tensor([-0.1134], requires_grad=True)x^Parameter containing:
# tensor([0.9949], requires_grad=True)
# Weights of synapse (0, 110): Main: Parameter containing:
# tensor([0.3619], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 111): Main: Parameter containing:
# tensor([0.4950], requires_grad=True)x^Parameter containing:
# tensor([0.9961], requires_grad=True)
# Weights of synapse (0, 112): Main: Parameter containing:
# tensor([-1.4266], requires_grad=True)x^Parameter containing:
# tensor([0.9947], requires_grad=True)
# Weights of synapse (0, 113): Main: Parameter containing:
# tensor([-1.8064], requires_grad=True)x^Parameter containing:
# tensor([1.4919], requires_grad=True)
# Weights of synapse (0, 114): Main: Parameter containing:
# tensor([1.6040], requires_grad=True)x^Parameter containing:
# tensor([0.9927], requires_grad=True)
# Weights of synapse (0, 115): Main: Parameter containing:
# tensor([-1.6579], requires_grad=True)x^Parameter containing:
# tensor([0.9871], requires_grad=True)
# Weights of synapse (0, 116): Main: Parameter containing:
# tensor([0.5013], requires_grad=True)x^Parameter containing:
# tensor([1.4920], requires_grad=True)
# Weights of synapse (0, 117): Main: Parameter containing:
# tensor([2.5064], requires_grad=True)x^Parameter containing:
# tensor([1.5001], requires_grad=True)
# Weights of synapse (0, 118): Main: Parameter containing:
# tensor([-0.6929], requires_grad=True)x^Parameter containing:
# tensor([0.9938], requires_grad=True)
# Weights of synapse (0, 119): Main: Parameter containing:
# tensor([0.4127], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (0, 120): Main: Parameter containing:
# tensor([-2.1806], requires_grad=True)x^Parameter containing:
# tensor([0.9775], requires_grad=True)
# Weights of synapse (0, 121): Main: Parameter containing:
# tensor([0.5003], requires_grad=True)x^Parameter containing:
# tensor([0.9921], requires_grad=True)
# Weights of synapse (0, 122): Main: Parameter containing:
# tensor([-2.0352], requires_grad=True)x^Parameter containing:
# tensor([0.9836], requires_grad=True)
# Weights of synapse (0, 123): Main: Parameter containing:
# tensor([-0.6802], requires_grad=True)x^Parameter containing:
# tensor([0.9944], requires_grad=True)
# Weights of synapse (0, 124): Main: Parameter containing:
# tensor([-1.4735], requires_grad=True)x^Parameter containing:
# tensor([0.9986], requires_grad=True)
# Weights of synapse (0, 125): Main: Parameter containing:
# tensor([0.5912], requires_grad=True)x^Parameter containing:
# tensor([1.4936], requires_grad=True)
# Weights of synapse (0, 126): Main: Parameter containing:
# tensor([-0.3822], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (0, 127): Main: Parameter containing:
# tensor([-0.6294], requires_grad=True)x^Parameter containing:
# tensor([1.4934], requires_grad=True)
# Weights of synapse (0, 128): Main: Parameter containing:
# tensor([-0.8318], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 129): Main: Parameter containing:
# tensor([1.4795], requires_grad=True)x^Parameter containing:
# tensor([0.9916], requires_grad=True)
# Weights of synapse (0, 130): Main: Parameter containing:
# tensor([-2.4964], requires_grad=True)x^Parameter containing:
# tensor([1.4886], requires_grad=True)
# Weights of synapse (0, 131): Main: Parameter containing:
# tensor([0.0600], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 132): Main: Parameter containing:
# tensor([-0.5060], requires_grad=True)x^Parameter containing:
# tensor([0.9936], requires_grad=True)
# Weights of synapse (0, 133): Main: Parameter containing:
# tensor([-0.9868], requires_grad=True)x^Parameter containing:
# tensor([1.4937], requires_grad=True)
# Weights of synapse (0, 134): Main: Parameter containing:
# tensor([-2.3015], requires_grad=True)x^Parameter containing:
# tensor([0.9804], requires_grad=True)
# Weights of synapse (0, 135): Main: Parameter containing:
# tensor([-0.9333], requires_grad=True)x^Parameter containing:
# tensor([0.9905], requires_grad=True)
# Weights of synapse (0, 136): Main: Parameter containing:
# tensor([0.2760], requires_grad=True)x^Parameter containing:
# tensor([0.9942], requires_grad=True)
# Weights of synapse (0, 137): Main: Parameter containing:
# tensor([0.7509], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 138): Main: Parameter containing:
# tensor([0.2727], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 139): Main: Parameter containing:
# tensor([0.6910], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 140): Main: Parameter containing:
# tensor([-0.4804], requires_grad=True)x^Parameter containing:
# tensor([1.4934], requires_grad=True)
# Weights of synapse (0, 141): Main: Parameter containing:
# tensor([-0.5759], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (0, 142): Main: Parameter containing:
# tensor([1.0945], requires_grad=True)x^Parameter containing:
# tensor([0.9910], requires_grad=True)
# Weights of synapse (0, 143): Main: Parameter containing:
# tensor([-1.3617], requires_grad=True)x^Parameter containing:
# tensor([0.9890], requires_grad=True)
# Weights of synapse (0, 144): Main: Parameter containing:
# tensor([1.0259], requires_grad=True)x^Parameter containing:
# tensor([0.9962], requires_grad=True)
# Weights of synapse (0, 145): Main: Parameter containing:
# tensor([-1.6696], requires_grad=True)x^Parameter containing:
# tensor([0.9898], requires_grad=True)
# Weights of synapse (0, 146): Main: Parameter containing:
# tensor([1.1854], requires_grad=True)x^Parameter containing:
# tensor([0.9937], requires_grad=True)
# Weights of synapse (0, 147): Main: Parameter containing:
# tensor([-0.5416], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (0, 148): Main: Parameter containing:
# tensor([-0.0353], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 149): Main: Parameter containing:
# tensor([0.9283], requires_grad=True)x^Parameter containing:
# tensor([1.4919], requires_grad=True)
# Weights of synapse (0, 150): Main: Parameter containing:
# tensor([0.9542], requires_grad=True)x^Parameter containing:
# tensor([0.9917], requires_grad=True)
# Weights of synapse (0, 151): Main: Parameter containing:
# tensor([-0.0264], requires_grad=True)x^Parameter containing:
# tensor([0.9954], requires_grad=True)
# Weights of synapse (0, 152): Main: Parameter containing:
# tensor([1.3639], requires_grad=True)x^Parameter containing:
# tensor([1.4951], requires_grad=True)
# Weights of synapse (0, 153): Main: Parameter containing:
# tensor([-0.1038], requires_grad=True)x^Parameter containing:
# tensor([0.9956], requires_grad=True)
# Weights of synapse (0, 154): Main: Parameter containing:
# tensor([0.1208], requires_grad=True)x^Parameter containing:
# tensor([0.9951], requires_grad=True)
# Weights of synapse (0, 155): Main: Parameter containing:
# tensor([0.0421], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 156): Main: Parameter containing:
# tensor([1.0287], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 157): Main: Parameter containing:
# tensor([1.7179], requires_grad=True)x^Parameter containing:
# tensor([0.9843], requires_grad=True)
# Weights of synapse (0, 158): Main: Parameter containing:
# tensor([0.9577], requires_grad=True)x^Parameter containing:
# tensor([1.4937], requires_grad=True)
# Weights of synapse (0, 159): Main: Parameter containing:
# tensor([-1.3047], requires_grad=True)x^Parameter containing:
# tensor([0.9951], requires_grad=True)
# Weights of synapse (0, 160): Main: Parameter containing:
# tensor([-0.7883], requires_grad=True)x^Parameter containing:
# tensor([0.9960], requires_grad=True)
# Weights of synapse (0, 161): Main: Parameter containing:
# tensor([-0.1484], requires_grad=True)x^Parameter containing:
# tensor([0.9954], requires_grad=True)
# Weights of synapse (0, 162): Main: Parameter containing:
# tensor([0.3650], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 163): Main: Parameter containing:
# tensor([-0.2154], requires_grad=True)x^Parameter containing:
# tensor([0.9960], requires_grad=True)
# Weights of synapse (0, 164): Main: Parameter containing:
# tensor([-1.3809], requires_grad=True)x^Parameter containing:
# tensor([0.9930], requires_grad=True)
# Weights of synapse (0, 165): Main: Parameter containing:
# tensor([0.2541], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (0, 166): Main: Parameter containing:
# tensor([0.9079], requires_grad=True)x^Parameter containing:
# tensor([1.4934], requires_grad=True)
# Weights of synapse (0, 167): Main: Parameter containing:
# tensor([-0.3977], requires_grad=True)x^Parameter containing:
# tensor([0.9955], requires_grad=True)
# Weights of synapse (0, 168): Main: Parameter containing:
# tensor([0.2309], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 169): Main: Parameter containing:
# tensor([-1.1077], requires_grad=True)x^Parameter containing:
# tensor([0.9937], requires_grad=True)
# Weights of synapse (0, 170): Main: Parameter containing:
# tensor([-0.3768], requires_grad=True)x^Parameter containing:
# tensor([0.9960], requires_grad=True)
# Weights of synapse (0, 171): Main: Parameter containing:
# tensor([-0.4666], requires_grad=True)x^Parameter containing:
# tensor([1.4932], requires_grad=True)
# Weights of synapse (0, 172): Main: Parameter containing:
# tensor([0.5652], requires_grad=True)x^Parameter containing:
# tensor([0.9945], requires_grad=True)
# Weights of synapse (0, 173): Main: Parameter containing:
# tensor([-0.7780], requires_grad=True)x^Parameter containing:
# tensor([1.4922], requires_grad=True)
# Weights of synapse (0, 174): Main: Parameter containing:
# tensor([-2.1567], requires_grad=True)x^Parameter containing:
# tensor([1.4889], requires_grad=True)
# Weights of synapse (0, 175): Main: Parameter containing:
# tensor([0.2038], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 176): Main: Parameter containing:
# tensor([-2.0139], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 177): Main: Parameter containing:
# tensor([-0.8962], requires_grad=True)x^Parameter containing:
# tensor([1.4903], requires_grad=True)
# Weights of synapse (0, 178): Main: Parameter containing:
# tensor([-0.4490], requires_grad=True)x^Parameter containing:
# tensor([0.9958], requires_grad=True)
# Weights of synapse (0, 179): Main: Parameter containing:
# tensor([1.2288], requires_grad=True)x^Parameter containing:
# tensor([0.9943], requires_grad=True)
# Weights of synapse (0, 180): Main: Parameter containing:
# tensor([0.3360], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (0, 181): Main: Parameter containing:
# tensor([1.0152], requires_grad=True)x^Parameter containing:
# tensor([1.4910], requires_grad=True)
# Weights of synapse (0, 182): Main: Parameter containing:
# tensor([-0.5453], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 183): Main: Parameter containing:
# tensor([0.1402], requires_grad=True)x^Parameter containing:
# tensor([0.9947], requires_grad=True)
# Weights of synapse (0, 184): Main: Parameter containing:
# tensor([-1.1987], requires_grad=True)x^Parameter containing:
# tensor([0.9933], requires_grad=True)
# Weights of synapse (0, 185): Main: Parameter containing:
# tensor([-0.5527], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 186): Main: Parameter containing:
# tensor([-0.4023], requires_grad=True)x^Parameter containing:
# tensor([0.9962], requires_grad=True)
# Weights of synapse (0, 187): Main: Parameter containing:
# tensor([-1.5099], requires_grad=True)x^Parameter containing:
# tensor([1.4904], requires_grad=True)
# Weights of synapse (0, 188): Main: Parameter containing:
# tensor([1.1430], requires_grad=True)x^Parameter containing:
# tensor([0.9887], requires_grad=True)
# Weights of synapse (0, 189): Main: Parameter containing:
# tensor([-0.5642], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 190): Main: Parameter containing:
# tensor([-0.6382], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 191): Main: Parameter containing:
# tensor([-1.3512], requires_grad=True)x^Parameter containing:
# tensor([1.4877], requires_grad=True)
# Weights of synapse (0, 192): Main: Parameter containing:
# tensor([1.7267], requires_grad=True)x^Parameter containing:
# tensor([0.9932], requires_grad=True)
# Weights of synapse (0, 193): Main: Parameter containing:
# tensor([1.3281], requires_grad=True)x^Parameter containing:
# tensor([0.9870], requires_grad=True)
# Weights of synapse (0, 194): Main: Parameter containing:
# tensor([-0.2129], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 195): Main: Parameter containing:
# tensor([-1.4100], requires_grad=True)x^Parameter containing:
# tensor([1.4907], requires_grad=True)
# Weights of synapse (0, 196): Main: Parameter containing:
# tensor([1.8074], requires_grad=True)x^Parameter containing:
# tensor([1.4963], requires_grad=True)
# Weights of synapse (0, 197): Main: Parameter containing:
# tensor([1.2673], requires_grad=True)x^Parameter containing:
# tensor([1.4920], requires_grad=True)
# Weights of synapse (0, 198): Main: Parameter containing:
# tensor([-1.5086], requires_grad=True)x^Parameter containing:
# tensor([0.9939], requires_grad=True)
# Weights of synapse (0, 199): Main: Parameter containing:
# tensor([-1.7024], requires_grad=True)x^Parameter containing:
# tensor([0.9879], requires_grad=True)
# Weights of synapse (0, 200): Main: Parameter containing:
# tensor([1.1962], requires_grad=True)x^Parameter containing:
# tensor([0.9881], requires_grad=True)
# Weights of synapse (0, 201): Main: Parameter containing:
# tensor([0.7503], requires_grad=True)x^Parameter containing:
# tensor([1.4918], requires_grad=True)
# Weights of synapse (0, 202): Main: Parameter containing:
# tensor([-0.9195], requires_grad=True)x^Parameter containing:
# tensor([0.9916], requires_grad=True)
# Weights of synapse (0, 203): Main: Parameter containing:
# tensor([-1.1306], requires_grad=True)x^Parameter containing:
# tensor([0.9895], requires_grad=True)
# Weights of synapse (0, 204): Main: Parameter containing:
# tensor([-1.0227], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 205): Main: Parameter containing:
# tensor([0.6549], requires_grad=True)x^Parameter containing:
# tensor([1.4933], requires_grad=True)
# Weights of synapse (0, 206): Main: Parameter containing:
# tensor([0.1485], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 207): Main: Parameter containing:
# tensor([0.0635], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 208): Main: Parameter containing:
# tensor([0.3020], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 209): Main: Parameter containing:
# tensor([0.0283], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 210): Main: Parameter containing:
# tensor([-2.7657], requires_grad=True)x^Parameter containing:
# tensor([0.9816], requires_grad=True)
# Weights of synapse (0, 211): Main: Parameter containing:
# tensor([0.1314], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 212): Main: Parameter containing:
# tensor([0.1037], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (0, 213): Main: Parameter containing:
# tensor([-0.4965], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (0, 214): Main: Parameter containing:
# tensor([0.1651], requires_grad=True)x^Parameter containing:
# tensor([0.9948], requires_grad=True)
# Weights of synapse (0, 215): Main: Parameter containing:
# tensor([-1.4341], requires_grad=True)x^Parameter containing:
# tensor([1.4951], requires_grad=True)
# Weights of synapse (0, 216): Main: Parameter containing:
# tensor([-0.3654], requires_grad=True)x^Parameter containing:
# tensor([0.9961], requires_grad=True)
# Weights of synapse (0, 217): Main: Parameter containing:
# tensor([-1.9289], requires_grad=True)x^Parameter containing:
# tensor([0.9850], requires_grad=True)
# Weights of synapse (0, 218): Main: Parameter containing:
# tensor([-0.2246], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (0, 219): Main: Parameter containing:
# tensor([0.7340], requires_grad=True)x^Parameter containing:
# tensor([0.9927], requires_grad=True)
# Weights of synapse (0, 220): Main: Parameter containing:
# tensor([-0.9127], requires_grad=True)x^Parameter containing:
# tensor([0.9919], requires_grad=True)
# Weights of synapse (0, 221): Main: Parameter containing:
# tensor([0.3338], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (0, 222): Main: Parameter containing:
# tensor([-0.3835], requires_grad=True)x^Parameter containing:
# tensor([1.4933], requires_grad=True)
# Weights of synapse (0, 223): Main: Parameter containing:
# tensor([-1.0178], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 224): Main: Parameter containing:
# tensor([0.1567], requires_grad=True)x^Parameter containing:
# tensor([0.9948], requires_grad=True)
# Weights of synapse (0, 225): Main: Parameter containing:
# tensor([0.4632], requires_grad=True)x^Parameter containing:
# tensor([0.9951], requires_grad=True)
# Weights of synapse (0, 226): Main: Parameter containing:
# tensor([0.8805], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 227): Main: Parameter containing:
# tensor([0.4890], requires_grad=True)x^Parameter containing:
# tensor([0.9962], requires_grad=True)
# Weights of synapse (0, 228): Main: Parameter containing:
# tensor([0.0997], requires_grad=True)x^Parameter containing:
# tensor([0.9951], requires_grad=True)
# Weights of synapse (0, 229): Main: Parameter containing:
# tensor([0.1765], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 230): Main: Parameter containing:
# tensor([-0.8367], requires_grad=True)x^Parameter containing:
# tensor([1.4919], requires_grad=True)
# Weights of synapse (0, 231): Main: Parameter containing:
# tensor([0.3216], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 232): Main: Parameter containing:
# tensor([0.4778], requires_grad=True)x^Parameter containing:
# tensor([1.4933], requires_grad=True)
# Weights of synapse (0, 233): Main: Parameter containing:
# tensor([-0.1922], requires_grad=True)x^Parameter containing:
# tensor([0.9955], requires_grad=True)
# Weights of synapse (0, 234): Main: Parameter containing:
# tensor([-2.3308], requires_grad=True)x^Parameter containing:
# tensor([1.4947], requires_grad=True)
# Weights of synapse (0, 235): Main: Parameter containing:
# tensor([2.9792], requires_grad=True)x^Parameter containing:
# tensor([0.9858], requires_grad=True)
# Weights of synapse (0, 236): Main: Parameter containing:
# tensor([-1.1171], requires_grad=True)x^Parameter containing:
# tensor([1.4938], requires_grad=True)
# Weights of synapse (0, 237): Main: Parameter containing:
# tensor([-0.4708], requires_grad=True)x^Parameter containing:
# tensor([1.4947], requires_grad=True)
# Weights of synapse (0, 238): Main: Parameter containing:
# tensor([-0.7172], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 239): Main: Parameter containing:
# tensor([0.1021], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 240): Main: Parameter containing:
# tensor([0.3178], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 241): Main: Parameter containing:
# tensor([0.6389], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (0, 242): Main: Parameter containing:
# tensor([-0.3686], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 243): Main: Parameter containing:
# tensor([-1.0181], requires_grad=True)x^Parameter containing:
# tensor([0.9896], requires_grad=True)
# Weights of synapse (0, 244): Main: Parameter containing:
# tensor([0.9013], requires_grad=True)x^Parameter containing:
# tensor([0.9890], requires_grad=True)
# Weights of synapse (0, 245): Main: Parameter containing:
# tensor([0.3235], requires_grad=True)x^Parameter containing:
# tensor([1.4935], requires_grad=True)
# Weights of synapse (0, 246): Main: Parameter containing:
# tensor([0.5008], requires_grad=True)x^Parameter containing:
# tensor([1.4914], requires_grad=True)
# Weights of synapse (0, 247): Main: Parameter containing:
# tensor([0.9659], requires_grad=True)x^Parameter containing:
# tensor([1.4923], requires_grad=True)
# Weights of synapse (0, 248): Main: Parameter containing:
# tensor([-0.2363], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 249): Main: Parameter containing:
# tensor([-0.2773], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 250): Main: Parameter containing:
# tensor([-0.8512], requires_grad=True)x^Parameter containing:
# tensor([0.9915], requires_grad=True)
# Weights of synapse (0, 251): Main: Parameter containing:
# tensor([0.3354], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 252): Main: Parameter containing:
# tensor([0.8237], requires_grad=True)x^Parameter containing:
# tensor([0.9978], requires_grad=True)
# Weights of synapse (0, 253): Main: Parameter containing:
# tensor([1.0801], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (0, 254): Main: Parameter containing:
# tensor([0.5822], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (0, 255): Main: Parameter containing:
# tensor([-0.3554], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 256): Main: Parameter containing:
# tensor([-0.0729], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 257): Main: Parameter containing:
# tensor([0.3708], requires_grad=True)x^Parameter containing:
# tensor([0.9960], requires_grad=True)
# Weights of synapse (0, 258): Main: Parameter containing:
# tensor([-0.4222], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (0, 259): Main: Parameter containing:
# tensor([-0.6727], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 260): Main: Parameter containing:
# tensor([-0.2544], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 261): Main: Parameter containing:
# tensor([1.0495], requires_grad=True)x^Parameter containing:
# tensor([1.4947], requires_grad=True)
# Weights of synapse (0, 262): Main: Parameter containing:
# tensor([-0.0120], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 263): Main: Parameter containing:
# tensor([-1.2544], requires_grad=True)x^Parameter containing:
# tensor([0.9930], requires_grad=True)
# Weights of synapse (0, 264): Main: Parameter containing:
# tensor([0.5362], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (0, 265): Main: Parameter containing:
# tensor([1.8495], requires_grad=True)x^Parameter containing:
# tensor([1.4946], requires_grad=True)
# Weights of synapse (0, 266): Main: Parameter containing:
# tensor([-1.1397], requires_grad=True)x^Parameter containing:
# tensor([1.4963], requires_grad=True)
# Weights of synapse (0, 267): Main: Parameter containing:
# tensor([-1.5392], requires_grad=True)x^Parameter containing:
# tensor([0.9918], requires_grad=True)
# Weights of synapse (0, 268): Main: Parameter containing:
# tensor([-0.2994], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 269): Main: Parameter containing:
# tensor([-0.5970], requires_grad=True)x^Parameter containing:
# tensor([1.4921], requires_grad=True)
# Weights of synapse (0, 270): Main: Parameter containing:
# tensor([1.4044], requires_grad=True)x^Parameter containing:
# tensor([0.9876], requires_grad=True)
# Weights of synapse (0, 271): Main: Parameter containing:
# tensor([-0.6846], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 272): Main: Parameter containing:
# tensor([-1.5063], requires_grad=True)x^Parameter containing:
# tensor([1.4917], requires_grad=True)
# Weights of synapse (0, 273): Main: Parameter containing:
# tensor([0.0092], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 274): Main: Parameter containing:
# tensor([0.5350], requires_grad=True)x^Parameter containing:
# tensor([1.4934], requires_grad=True)
# Weights of synapse (0, 275): Main: Parameter containing:
# tensor([-0.9838], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 276): Main: Parameter containing:
# tensor([-1.0984], requires_grad=True)x^Parameter containing:
# tensor([1.4913], requires_grad=True)
# Weights of synapse (0, 277): Main: Parameter containing:
# tensor([-1.0912], requires_grad=True)x^Parameter containing:
# tensor([0.9976], requires_grad=True)
# Weights of synapse (0, 278): Main: Parameter containing:
# tensor([0.2799], requires_grad=True)x^Parameter containing:
# tensor([0.9942], requires_grad=True)
# Weights of synapse (0, 279): Main: Parameter containing:
# tensor([0.3542], requires_grad=True)x^Parameter containing:
# tensor([0.9943], requires_grad=True)
# Weights of synapse (0, 280): Main: Parameter containing:
# tensor([0.9750], requires_grad=True)x^Parameter containing:
# tensor([1.4934], requires_grad=True)
# Weights of synapse (0, 281): Main: Parameter containing:
# tensor([1.5201], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 282): Main: Parameter containing:
# tensor([-0.4892], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 283): Main: Parameter containing:
# tensor([2.3006], requires_grad=True)x^Parameter containing:
# tensor([0.9863], requires_grad=True)
# Weights of synapse (0, 284): Main: Parameter containing:
# tensor([-0.7962], requires_grad=True)x^Parameter containing:
# tensor([1.4919], requires_grad=True)
# Weights of synapse (0, 285): Main: Parameter containing:
# tensor([0.8193], requires_grad=True)x^Parameter containing:
# tensor([1.4944], requires_grad=True)
# Weights of synapse (0, 286): Main: Parameter containing:
# tensor([-0.1233], requires_grad=True)x^Parameter containing:
# tensor([1.4930], requires_grad=True)
# Weights of synapse (0, 287): Main: Parameter containing:
# tensor([0.0982], requires_grad=True)x^Parameter containing:
# tensor([0.9956], requires_grad=True)
# Weights of synapse (0, 288): Main: Parameter containing:
# tensor([-0.5523], requires_grad=True)x^Parameter containing:
# tensor([0.9943], requires_grad=True)
# Weights of synapse (0, 289): Main: Parameter containing:
# tensor([-0.4799], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 290): Main: Parameter containing:
# tensor([-0.0138], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 291): Main: Parameter containing:
# tensor([-0.4411], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 292): Main: Parameter containing:
# tensor([1.3588], requires_grad=True)x^Parameter containing:
# tensor([0.9827], requires_grad=True)
# Weights of synapse (0, 293): Main: Parameter containing:
# tensor([-0.4210], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (0, 294): Main: Parameter containing:
# tensor([-0.1675], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (0, 295): Main: Parameter containing:
# tensor([-0.4449], requires_grad=True)x^Parameter containing:
# tensor([0.9932], requires_grad=True)
# Weights of synapse (0, 296): Main: Parameter containing:
# tensor([-0.4157], requires_grad=True)x^Parameter containing:
# tensor([1.4936], requires_grad=True)
# Weights of synapse (0, 297): Main: Parameter containing:
# tensor([1.2322], requires_grad=True)x^Parameter containing:
# tensor([1.4932], requires_grad=True)
# Weights of synapse (0, 298): Main: Parameter containing:
# tensor([0.9649], requires_grad=True)x^Parameter containing:
# tensor([1.4922], requires_grad=True)
# Weights of synapse (0, 299): Main: Parameter containing:
# tensor([1.1266], requires_grad=True)x^Parameter containing:
# tensor([1.4941], requires_grad=True)
# Weights of synapse (0, 300): Main: Parameter containing:
# tensor([-0.6167], requires_grad=True)x^Parameter containing:
# tensor([0.9944], requires_grad=True)
# Weights of synapse (0, 301): Main: Parameter containing:
# tensor([0.1570], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (0, 302): Main: Parameter containing:
# tensor([-2.8989], requires_grad=True)x^Parameter containing:
# tensor([0.9662], requires_grad=True)
# Weights of synapse (0, 303): Main: Parameter containing:
# tensor([-0.1543], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (0, 304): Main: Parameter containing:
# tensor([-1.2231], requires_grad=True)x^Parameter containing:
# tensor([0.9932], requires_grad=True)
# Weights of synapse (0, 305): Main: Parameter containing:
# tensor([-1.2419], requires_grad=True)x^Parameter containing:
# tensor([1.4923], requires_grad=True)
# Weights of synapse (0, 306): Main: Parameter containing:
# tensor([0.9849], requires_grad=True)x^Parameter containing:
# tensor([0.9932], requires_grad=True)
# Weights of synapse (0, 307): Main: Parameter containing:
# tensor([-0.6662], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (0, 308): Main: Parameter containing:
# tensor([-0.7877], requires_grad=True)x^Parameter containing:
# tensor([1.4915], requires_grad=True)
# Weights of synapse (0, 309): Main: Parameter containing:
# tensor([0.7008], requires_grad=True)x^Parameter containing:
# tensor([1.4932], requires_grad=True)
# Weights of synapse (0, 310): Main: Parameter containing:
# tensor([0.7295], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (0, 311): Main: Parameter containing:
# ...
# tensor([1.4942], requires_grad=True)
# Weights of synapse (9, 257): Main: Parameter containing:
# tensor([1.8433], requires_grad=True)x^Parameter containing:
# tensor([0.9887], requires_grad=True)
# Weights of synapse (9, 258): Main: Parameter containing:
# tensor([-1.6976], requires_grad=True)x^Parameter containing:
# tensor([1.4922], requires_grad=True)
# Weights of synapse (9, 259): Main: Parameter containing:
# tensor([0.6187], requires_grad=True)x^Parameter containing:
# tensor([1.4936], requires_grad=True)
# Weights of synapse (9, 260): Main: Parameter containing:
# tensor([-0.6139], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (9, 261): Main: Parameter containing:
# tensor([1.2838], requires_grad=True)x^Parameter containing:
# tensor([1.4921], requires_grad=True)
# Weights of synapse (9, 262): Main: Parameter containing:
# tensor([0.7943], requires_grad=True)x^Parameter containing:
# tensor([0.9948], requires_grad=True)
# Weights of synapse (9, 263): Main: Parameter containing:
# tensor([-0.5704], requires_grad=True)x^Parameter containing:
# tensor([1.4939], requires_grad=True)
# Weights of synapse (9, 264): Main: Parameter containing:
# tensor([1.2238], requires_grad=True)x^Parameter containing:
# tensor([1.4924], requires_grad=True)
# Weights of synapse (9, 265): Main: Parameter containing:
# tensor([-0.0473], requires_grad=True)x^Parameter containing:
# tensor([0.9954], requires_grad=True)
# Weights of synapse (9, 266): Main: Parameter containing:
# tensor([-0.3395], requires_grad=True)x^Parameter containing:
# tensor([0.9969], requires_grad=True)
# Weights of synapse (9, 267): Main: Parameter containing:
# tensor([-0.1859], requires_grad=True)x^Parameter containing:
# tensor([0.9960], requires_grad=True)
# Weights of synapse (9, 268): Main: Parameter containing:
# tensor([-0.2945], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 269): Main: Parameter containing:
# tensor([-1.2748], requires_grad=True)x^Parameter containing:
# tensor([0.9904], requires_grad=True)
# Weights of synapse (9, 270): Main: Parameter containing:
# tensor([1.7850], requires_grad=True)x^Parameter containing:
# tensor([0.9895], requires_grad=True)
# Weights of synapse (9, 271): Main: Parameter containing:
# tensor([-0.0171], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (9, 272): Main: Parameter containing:
# tensor([1.1864], requires_grad=True)x^Parameter containing:
# tensor([0.9922], requires_grad=True)
# Weights of synapse (9, 273): Main: Parameter containing:
# tensor([0.0222], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (9, 274): Main: Parameter containing:
# tensor([1.2019], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (9, 275): Main: Parameter containing:
# tensor([-1.2048], requires_grad=True)x^Parameter containing:
# tensor([1.4913], requires_grad=True)
# Weights of synapse (9, 276): Main: Parameter containing:
# tensor([1.8378], requires_grad=True)x^Parameter containing:
# tensor([0.9889], requires_grad=True)
# Weights of synapse (9, 277): Main: Parameter containing:
# tensor([0.6435], requires_grad=True)x^Parameter containing:
# tensor([0.9961], requires_grad=True)
# Weights of synapse (9, 278): Main: Parameter containing:
# tensor([-1.2502], requires_grad=True)x^Parameter containing:
# tensor([0.9909], requires_grad=True)
# Weights of synapse (9, 279): Main: Parameter containing:
# tensor([1.1435], requires_grad=True)x^Parameter containing:
# tensor([1.4931], requires_grad=True)
# Weights of synapse (9, 280): Main: Parameter containing:
# tensor([0.9328], requires_grad=True)x^Parameter containing:
# tensor([1.4907], requires_grad=True)
# Weights of synapse (9, 281): Main: Parameter containing:
# tensor([1.4159], requires_grad=True)x^Parameter containing:
# tensor([0.9929], requires_grad=True)
# Weights of synapse (9, 282): Main: Parameter containing:
# tensor([-0.4276], requires_grad=True)x^Parameter containing:
# tensor([0.9948], requires_grad=True)
# Weights of synapse (9, 283): Main: Parameter containing:
# tensor([0.1415], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (9, 284): Main: Parameter containing:
# tensor([-1.0541], requires_grad=True)x^Parameter containing:
# tensor([0.9983], requires_grad=True)
# Weights of synapse (9, 285): Main: Parameter containing:
# tensor([0.0491], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (9, 286): Main: Parameter containing:
# tensor([-0.3543], requires_grad=True)x^Parameter containing:
# tensor([0.9943], requires_grad=True)
# Weights of synapse (9, 287): Main: Parameter containing:
# tensor([0.4074], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (9, 288): Main: Parameter containing:
# tensor([-0.2956], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (9, 289): Main: Parameter containing:
# tensor([-0.8132], requires_grad=True)x^Parameter containing:
# tensor([0.9929], requires_grad=True)
# Weights of synapse (9, 290): Main: Parameter containing:
# tensor([0.7815], requires_grad=True)x^Parameter containing:
# tensor([1.4933], requires_grad=True)
# Weights of synapse (9, 291): Main: Parameter containing:
# tensor([1.0622], requires_grad=True)x^Parameter containing:
# tensor([1.4913], requires_grad=True)
# Weights of synapse (9, 292): Main: Parameter containing:
# tensor([-0.6247], requires_grad=True)x^Parameter containing:
# tensor([0.9923], requires_grad=True)
# Weights of synapse (9, 293): Main: Parameter containing:
# tensor([0.2216], requires_grad=True)x^Parameter containing:
# tensor([1.4926], requires_grad=True)
# Weights of synapse (9, 294): Main: Parameter containing:
# tensor([-1.1309], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (9, 295): Main: Parameter containing:
# tensor([-0.6549], requires_grad=True)x^Parameter containing:
# tensor([0.9964], requires_grad=True)
# Weights of synapse (9, 296): Main: Parameter containing:
# tensor([0.8359], requires_grad=True)x^Parameter containing:
# tensor([0.9908], requires_grad=True)
# Weights of synapse (9, 297): Main: Parameter containing:
# tensor([-0.0900], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (9, 298): Main: Parameter containing:
# tensor([0.2124], requires_grad=True)x^Parameter containing:
# tensor([0.9956], requires_grad=True)
# Weights of synapse (9, 299): Main: Parameter containing:
# tensor([0.2486], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (9, 300): Main: Parameter containing:
# tensor([-0.4538], requires_grad=True)x^Parameter containing:
# tensor([0.9940], requires_grad=True)
# Weights of synapse (9, 301): Main: Parameter containing:
# tensor([-0.0418], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (9, 302): Main: Parameter containing:
# tensor([-0.2188], requires_grad=True)x^Parameter containing:
# tensor([0.9954], requires_grad=True)
# Weights of synapse (9, 303): Main: Parameter containing:
# tensor([0.2167], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (9, 304): Main: Parameter containing:
# tensor([1.9136], requires_grad=True)x^Parameter containing:
# tensor([0.9933], requires_grad=True)
# Weights of synapse (9, 305): Main: Parameter containing:
# tensor([-0.3638], requires_grad=True)x^Parameter containing:
# tensor([0.9950], requires_grad=True)
# Weights of synapse (9, 306): Main: Parameter containing:
# tensor([-0.7137], requires_grad=True)x^Parameter containing:
# tensor([0.9934], requires_grad=True)
# Weights of synapse (9, 307): Main: Parameter containing:
# tensor([0.6675], requires_grad=True)x^Parameter containing:
# tensor([1.4914], requires_grad=True)
# Weights of synapse (9, 308): Main: Parameter containing:
# tensor([0.4634], requires_grad=True)x^Parameter containing:
# tensor([0.9945], requires_grad=True)
# Weights of synapse (9, 309): Main: Parameter containing:
# tensor([0.4204], requires_grad=True)x^Parameter containing:
# tensor([0.9951], requires_grad=True)
# Weights of synapse (9, 310): Main: Parameter containing:
# tensor([-0.8799], requires_grad=True)x^Parameter containing:
# tensor([0.9927], requires_grad=True)
# Weights of synapse (9, 311): Main: Parameter containing:
# tensor([-0.7923], requires_grad=True)x^Parameter containing:
# tensor([1.4943], requires_grad=True)
# Weights of synapse (9, 312): Main: Parameter containing:
# tensor([-0.7975], requires_grad=True)x^Parameter containing:
# tensor([1.4922], requires_grad=True)
# Weights of synapse (9, 313): Main: Parameter containing:
# tensor([-0.4553], requires_grad=True)x^Parameter containing:
# tensor([0.9955], requires_grad=True)
# Weights of synapse (9, 314): Main: Parameter containing:
# tensor([-0.0337], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 315): Main: Parameter containing:
# tensor([-0.2441], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (9, 316): Main: Parameter containing:
# tensor([-0.5388], requires_grad=True)x^Parameter containing:
# tensor([0.9938], requires_grad=True)
# Weights of synapse (9, 317): Main: Parameter containing:
# tensor([0.3257], requires_grad=True)x^Parameter containing:
# tensor([0.9959], requires_grad=True)
# Weights of synapse (9, 318): Main: Parameter containing:
# tensor([-0.3628], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (9, 319): Main: Parameter containing:
# tensor([0.0243], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 320): Main: Parameter containing:
# tensor([0.0971], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 321): Main: Parameter containing:
# tensor([-0.6331], requires_grad=True)x^Parameter containing:
# tensor([0.9929], requires_grad=True)
# Weights of synapse (9, 322): Main: Parameter containing:
# tensor([-0.5999], requires_grad=True)x^Parameter containing:
# tensor([0.9947], requires_grad=True)
# Weights of synapse (9, 323): Main: Parameter containing:
# tensor([0.6992], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 324): Main: Parameter containing:
# tensor([-0.9343], requires_grad=True)x^Parameter containing:
# tensor([0.9936], requires_grad=True)
# Weights of synapse (9, 325): Main: Parameter containing:
# tensor([-1.1019], requires_grad=True)x^Parameter containing:
# tensor([0.9928], requires_grad=True)
# Weights of synapse (9, 326): Main: Parameter containing:
# tensor([0.3217], requires_grad=True)x^Parameter containing:
# tensor([1.4927], requires_grad=True)
# Weights of synapse (9, 327): Main: Parameter containing:
# tensor([0.5932], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 328): Main: Parameter containing:
# tensor([1.1889], requires_grad=True)x^Parameter containing:
# tensor([1.4915], requires_grad=True)
# Weights of synapse (9, 329): Main: Parameter containing:
# tensor([-0.2949], requires_grad=True)x^Parameter containing:
# tensor([1.4929], requires_grad=True)
# Weights of synapse (9, 330): Main: Parameter containing:
# tensor([-1.3098], requires_grad=True)x^Parameter containing:
# tensor([1.4915], requires_grad=True)
# Weights of synapse (9, 331): Main: Parameter containing:
# tensor([1.5509], requires_grad=True)x^Parameter containing:
# tensor([0.9905], requires_grad=True)
# Weights of synapse (9, 332): Main: Parameter containing:
# tensor([-0.1249], requires_grad=True)x^Parameter containing:
# tensor([0.9952], requires_grad=True)
# Weights of synapse (9, 333): Main: Parameter containing:
# tensor([1.2768], requires_grad=True)x^Parameter containing:
# tensor([0.9866], requires_grad=True)
# Weights of synapse (9, 334): Main: Parameter containing:
# tensor([1.4167], requires_grad=True)x^Parameter containing:
# tensor([1.4905], requires_grad=True)
# Weights of synapse (9, 335): Main: Parameter containing:
# tensor([0.5633], requires_grad=True)x^Parameter containing:
# tensor([0.9967], requires_grad=True)
# Weights of synapse (9, 336): Main: Parameter containing:
# tensor([0.7183], requires_grad=True)x^Parameter containing:
# tensor([1.4920], requires_grad=True)
# Weights of synapse (9, 337): Main: Parameter containing:
# tensor([0.3800], requires_grad=True)x^Parameter containing:
# tensor([0.9940], requires_grad=True)
# Weights of synapse (9, 338): Main: Parameter containing:
# tensor([0.2293], requires_grad=True)x^Parameter containing:
# tensor([0.9954], requires_grad=True)
# Weights of synapse (9, 339): Main: Parameter containing:
# tensor([1.1466], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)
# Weights of synapse (9, 340): Main: Parameter containing:
# tensor([1.6774], requires_grad=True)x^Parameter containing:
# tensor([1.4906], requires_grad=True)
# Weights of synapse (9, 341): Main: Parameter containing:
# tensor([1.7860], requires_grad=True)x^Parameter containing:
# tensor([1.4911], requires_grad=True)
# Weights of synapse (9, 342): Main: Parameter containing:
# tensor([-0.5836], requires_grad=True)x^Parameter containing:
# tensor([0.9959], requires_grad=True)
# Weights of synapse (9, 343): Main: Parameter containing:
# tensor([0.6908], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (9, 344): Main: Parameter containing:
# tensor([0.5163], requires_grad=True)x^Parameter containing:
# tensor([0.9945], requires_grad=True)
# Weights of synapse (9, 345): Main: Parameter containing:
# tensor([0.0045], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (9, 346): Main: Parameter containing:
# tensor([0.7659], requires_grad=True)x^Parameter containing:
# tensor([0.9923], requires_grad=True)
# Weights of synapse (9, 347): Main: Parameter containing:
# tensor([0.0162], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (9, 348): Main: Parameter containing:
# tensor([-2.4865], requires_grad=True)x^Parameter containing:
# tensor([0.9802], requires_grad=True)
# Weights of synapse (9, 349): Main: Parameter containing:
# tensor([-0.6697], requires_grad=True)x^Parameter containing:
# tensor([0.9937], requires_grad=True)
# Weights of synapse (9, 350): Main: Parameter containing:
# tensor([-1.2358], requires_grad=True)x^Parameter containing:
# tensor([0.9916], requires_grad=True)
# Weights of synapse (9, 351): Main: Parameter containing:
# tensor([1.7144], requires_grad=True)x^Parameter containing:
# tensor([1.4909], requires_grad=True)
# Weights of synapse (9, 352): Main: Parameter containing:
# tensor([-0.1250], requires_grad=True)x^Parameter containing:
# tensor([0.9953], requires_grad=True)
# Weights of synapse (9, 353): Main: Parameter containing:
# tensor([0.3892], requires_grad=True)x^Parameter containing:
# tensor([0.9948], requires_grad=True)
# Weights of synapse (9, 354): Main: Parameter containing:
# tensor([-0.7269], requires_grad=True)x^Parameter containing:
# tensor([1.4922], requires_grad=True)
# Weights of synapse (9, 355): Main: Parameter containing:
# tensor([0.3583], requires_grad=True)x^Parameter containing:
# tensor([0.9957], requires_grad=True)
# Weights of synapse (9, 356): Main: Parameter containing:
# tensor([-1.2402], requires_grad=True)x^Parameter containing:
# tensor([0.9914], requires_grad=True)
# Weights of synapse (9, 357): Main: Parameter containing:
# tensor([-0.2924], requires_grad=True)x^Parameter containing:
# tensor([0.9941], requires_grad=True)
# Weights of synapse (9, 358): Main: Parameter containing:
# tensor([0.0092], requires_grad=True)x^Parameter containing:
# tensor([1.4928], requires_grad=True)
# Weights of synapse (9, 359): Main: Parameter containing:
# tensor([0.5034], requires_grad=True)x^Parameter containing:
# tensor([1.4925], requires_grad=True)

# %%
# TODO: report test performance of best model

test_acc = test('best_model.pth', test_loader)
print(test_acc)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 3
#       1 # TODO: report test performance of best model
# ----> 3 test_acc = test('best_model.pth', test_loader)
#       4 print(test_acc)
#
# Cell In[19], line 5, in test(model_path, test_loader)
#       1 def test(model_path, test_loader):
#       2   # TODO: test function for your trained model, load your best model
#       3   # use the provided test loader
#       4   # return the test accuracy
# ----> 5   model = torch.load(model_path)
#       6   model.eval()
#       7   with torch.no_grad():
#
# File ~/anaconda3/envs/mlenv/lib/python3.11/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/mlenv/lib/python3.11/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File ~/anaconda3/envs/mlenv/lib/python3.11/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best_model.pth'
